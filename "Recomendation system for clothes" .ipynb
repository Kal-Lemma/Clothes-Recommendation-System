# %%
import pandas as pd 
import numpy as np 
from pandas.io.json import json_normalize
import json 
from surprise import Dataset, Reader
from surprise import accuracy
from surprise.model_selection.split import train_test_split

# %%
df = pd.read_json('modcloth_final_data.json', lines = True)
df
#LOADING dataframe
# Out:
#        bra size bust   category cup size    fit    height  hips  item_id  \
# 0          34.0   36        new        d  small   5ft 6in  38.0   123373
# 1          36.0  NaN        new        b  small   5ft 2in  30.0   123373
# 2          32.0  NaN        new        b  small   5ft 7in   NaN   123373
# 3           NaN  NaN        new     dd/e    fit       NaN   NaN   123373
# 4          36.0  NaN        new        b  small   5ft 2in   NaN   123373
# 5          36.0  NaN        new        c  small   5ft 4in  41.0   123373
# 6          32.0  NaN        new        b  large   5ft 3in   NaN   123373
# 7          38.0  NaN        new        d  small   5ft 5in  42.0   123373
# 8          42.0  NaN        new        d  small  5ft 10in  50.0   123373
# 9          36.0   39        new     dd/e    fit   5ft 6in  41.0   123373
# 10         40.0  NaN        new        d  small   5ft 6in  49.0   123373
# 11         44.0  NaN        new    ddd/f  small   5ft 4in  60.0   123373
# 12         34.0  NaN        new        c    fit   5ft 5in   NaN   123373
# 13         34.0  NaN        new     dd/e    fit   5ft 5in   NaN   123373
# 14         34.0  NaN        new        b    fit   5ft 3in  36.0   123373
# 15         40.0  NaN        new        c    fit   5ft 4in  50.0   123373
# 16         36.0  NaN        new        d    fit   5ft 2in  44.0   123373
# 17         36.0  NaN        new   dddd/g  large       NaN   NaN   123373
# 18         36.0  NaN        new        d  large   5ft 8in  39.0   123373
# 19         34.0  NaN        new     dd/e    fit   5ft 5in  35.0   123373
# 20         36.0  NaN        new     dd/e  large       5ft  38.0   123373
# 21         34.0  NaN        new        b  large   5ft 7in   NaN   123373
# 22         34.0  NaN        new     dd/e  small   5ft 9in  34.0   123373
# 23         34.0   34        new        c  small   5ft 1in  32.0   123373
# 24         38.0  NaN        new        d    fit   5ft 4in   NaN   123373
# 25         34.0  NaN        new        c  small   5ft 1in   NaN   123373
# 26         46.0  NaN        new        d    fit   5ft 3in   NaN   123373
# 27         34.0   36        new        c  small   5ft 6in  35.0   123373
# 28         44.0  NaN        new   dddd/g    fit   5ft 4in  48.0   123373
# 29         42.0  NaN        new     dd/e  small   5ft 7in  52.0   123373
# ...         ...  ...        ...      ...    ...       ...   ...      ...
# 82760      36.0  NaN  outerwear        b    fit  5ft 10in  36.0   807722
# 82761       NaN  NaN  outerwear      NaN    fit   5ft 2in   NaN   807722
# 82762      36.0  NaN  outerwear        d  small   5ft 4in  36.0   807722
# 82763      34.0  NaN  outerwear        c    fit   5ft 1in  30.0   807722
# 82764       NaN  NaN  outerwear      NaN    fit   5ft 3in   NaN   807722
# 82765      32.0  NaN  outerwear     dd/e    fit   5ft 8in   NaN   807722
# 82766      34.0  NaN  outerwear        c    fit   5ft 7in  36.0   807722
# 82767      36.0  NaN  outerwear        a  small   5ft 7in   NaN   807722
# 82768      34.0  NaN  outerwear        b    fit   5ft 3in  35.0   807722
# 82769      32.0   38  outerwear    ddd/f    fit   5ft 6in  41.0   807722
# 82770      36.0  NaN  outerwear     dd/e  small   5ft 7in  41.0   807722
# 82771      34.0  NaN  outerwear        b    fit   5ft 8in   NaN   807722
# 82772      34.0  NaN  outerwear        b    fit   5ft 6in  35.0   807722
# 82773      38.0  NaN  outerwear        b    fit   5ft 4in   NaN   807722
# 82774      34.0   34  outerwear        c    fit   5ft 2in  34.0   807722
# 82775      34.0  NaN  outerwear    ddd/f    fit   5ft 4in  40.0   807722
# 82776      36.0  NaN  outerwear        b    fit   5ft 2in  36.0   807722
# 82777      34.0  NaN  outerwear      NaN  small   5ft 4in  38.0   807722
# 82778      36.0  NaN  outerwear        d  small       5ft  38.0   807722
# 82779      36.0  NaN  outerwear     dd/e  small   5ft 7in  38.0   807722
# 82780      34.0  NaN  outerwear    ddd/f    fit   5ft 4in   NaN   807722
# 82781      34.0   38  outerwear     dd/e  small   5ft 6in  40.0   807722
# 82782      34.0  NaN  outerwear        c    fit   5ft 5in  37.0   807722
# 82783      32.0  NaN  outerwear        b    fit   5ft 2in  34.0   807722
# 82784      32.0  NaN  outerwear        a  large   5ft 1in  35.0   807722
# 82785      36.0  NaN  outerwear        b    fit   5ft 8in   NaN   807722
# 82786      34.0  NaN  outerwear    ddd/f  small   5ft 5in   NaN   807722
# 82787      32.0  NaN  outerwear   dddd/g    fit   5ft 4in  36.0   807722
# 82788       NaN  NaN  outerwear      NaN    fit   5ft 3in   NaN   807722
# 82789      32.0  NaN  outerwear        d    fit       6ft  39.0   807722
#
#               length  quality             review_summary  \
# 0         just right      5.0                        NaN
# 1         just right      3.0                        NaN
# 2      slightly long      2.0                        NaN
# 3         just right      5.0                        NaN
# 4      slightly long      5.0                        NaN
# 5         just right      5.0                        NaN
# 6         just right      1.0                        NaN
# 7         just right      5.0                        NaN
# 8         just right      4.0                        NaN
# 9         just right      5.0                        NaN
# 10        just right      4.0                        NaN
# 11        just right      5.0                        NaN
# 12        just right      5.0                        NaN
# 13        just right      4.0                        NaN
# 14        just right      5.0                        NaN
# 15        just right      4.0                        NaN
# 16        just right      5.0                        NaN
# 17        just right      4.0                        NaN
# 18        just right      4.0                        NaN
# 19        very short      1.0                        NaN
# 20     slightly long      5.0                        NaN
# 21        just right      5.0                        NaN
# 22        just right      4.0                        NaN
# 23        just right      5.0                        NaN
# 24        just right      4.0                        NaN
# 25        just right      5.0                        NaN
# 26        just right      5.0                        NaN
# 27     slightly long      5.0                        NaN
# 28        just right      5.0                        NaN
# 29        just right      4.0                        NaN
# ...              ...      ...                        ...
# 82760     just right      5.0  Soft and stylish, I'm obs
# 82761     just right      5.0             Love it!!!!! P
# 82762     just right      5.0   Was a bit hard to close,
# 82763     just right      5.0   This jacket has shoulder
# 82764     just right      5.0  Perfect for work dresses.
# 82765     just right      4.0  This jacket fits perfectl
# 82766     just right      5.0    What a fabulous blazer!
# 82767     just right      2.0   I took a gamble on the L
# 82768     just right      3.0  Good fit. Simple jacket b
# 82769     just right      3.0  Very flattering lightweig
# 82770     just right      5.0  Lovely jacket.  I removed
# 82771     just right      4.0   Great color and fit. You
# 82772     just right      5.0  Too many compliments to c
# 82773     just right      5.0  I'm in love with this bla
# 82774     just right      4.0  I really love this jacket
# 82775     just right      4.0  I love this jacket; it lo
# 82776     just right      5.0  Great quality and super a
# 82777     just right      4.0  Had to return  I'm usuall
# 82778  slightly long      5.0  This jacket is really nic
# 82779     just right      4.0  Got this in black and rec
# 82780     just right      4.0  stretchy, light weight, c
# 82781     just right      5.0  This looks so cute over d
# 82782     just right      3.0   Material was more causal
# 82783     just right      5.0  I was surprised by the ve
# 82784     just right      3.0   It ran a little big, and
# 82785     just right      4.0               Cute jacket!
# 82786  slightly long      5.0   It's a beautiful jacket.
# 82787     just right      5.0  I love this blazer. It is
# 82788     just right      4.0  I love this blazer!! I wo
# 82789     just right      4.0  I love this piece. I'm re
#
#                                              review_text  shoe size  \
# 0                                                    NaN        NaN
# 1                                                    NaN        NaN
# 2                                                    NaN        9.0
# 3                                                    NaN        NaN
# 4                                                    NaN        NaN
# 5                                                    NaN        NaN
# 6                                                    NaN        NaN
# 7                                                    NaN        8.5
# 8                                                    NaN       11.0
# 9                                                    NaN        9.0
# 10                                                   NaN        NaN
# 11                                                   NaN        NaN
# 12                                                   NaN        NaN
# 13                                                   NaN        NaN
# 14                                                   NaN        NaN
# 15                                                   NaN        NaN
# 16                                                   NaN        8.5
# 17                                                   NaN        NaN
# 18                                                   NaN        8.5
# 19                                                   NaN        NaN
# 20                                                   NaN        NaN
# 21                                                   NaN        7.0
# 22                                                   NaN        9.0
# 23                                                   NaN        7.0
# 24                                                   NaN        NaN
# 25                                                   NaN        NaN
# 26                                                   NaN        8.5
# 27                                                   NaN        NaN
# 28                                                   NaN        NaN
# 29                                                   NaN        NaN
# ...                                                  ...        ...
# 82760   Soft and stylish, I'm obsessed with this jacket!        NaN
# 82761                                     Love it!!!!! P        NaN
# 82762  Was a bit hard to close, but I was planning to...        NaN
# 82763  This jacket has shoulder pads in it  going to ...        5.5
# 82764                          Perfect for work dresses.        NaN
# 82765  This jacket fits perfectly and is super cool! ...        8.0
# 82766  What a fabulous blazer!  It's made of a thicke...        NaN
# 82767  I took a gamble on the L and unfortunately it ...        9.0
# 82768      Good fit. Simple jacket but can go with a lot        NaN
# 82769                Very flattering lightweight blazer.        8.0
# 82770  Lovely jacket.  I removed the shoulder pads an...        NaN
# 82771  Great color and fit. You can dress this up or ...        8.5
# 82772  Too many compliments to count...it's such a sh...        NaN
# 82773  I'm in love with this blazer.  It is so stretc...        NaN
# 82774  I really love this jacket. When I wore it abou...        7.5
# 82775  I love this jacket; it looks great with a lot ...        9.0
# 82776  Great quality and super adorable! Love, love l...        NaN
# 82777  Had to return  I'm usually a medium in shirts ...        NaN
# 82778  This jacket is really nice. Seems like it was ...        NaN
# 82779  Got this in black and received so many complim...        7.5
# 82780                      stretchy, light weight, comfy        NaN
# 82781  This looks so cute over dresses! I bought both...        6.5
# 82782  Material was more causal than I expected, but ...        NaN
# 82783  I was surprised by the very good quality of th...        6.0
# 82784  It ran a little big, and I'm not crazy about t...        6.5
# 82785                                       Cute jacket!        8.5
# 82786  It's a beautiful jacket. I love how it's knit ...        NaN
# 82787  I love this blazer. It is a great office piece...        NaN
# 82788  I love this blazer!! I wore it yesterday and g...        NaN
# 82789       I love this piece. I'm really happy with it!        NaN
#
#       shoe width  size  user_id           user_name  waist
# 0            NaN     7   991571               Emily   29.0
# 1            NaN    13   587883    sydneybraden2001   31.0
# 2            NaN     7   395665               Ugggh   30.0
# 3            NaN    21   875643        alexmeyer626    NaN
# 4            NaN    18   944840          dberrones1    NaN
# 5            NaN    11   162012         Doreenajane   27.0
# 6            NaN     5   114843         barbiejenks   26.0
# 7            NaN    11    58869           brettloie    NaN
# 8           wide    30   279568      francescaviola    NaN
# 9            NaN    13   950172        laurenpolzin    NaN
# 10           NaN    24   205796            micorson    NaN
# 11           NaN    33   422613             tera.oh    NaN
# 12           NaN     5    42840            kmj11492    NaN
# 13           NaN     7   767255  katherineoliviaman    NaN
# 14           NaN     3   510154            stacy233    NaN
# 15           NaN    27   780339         tamera.cole    NaN
# 16           NaN    18   936337         choircorgis    NaN
# 17           NaN    15   128353               Megan    NaN
# 18           NaN    15    21605               Carol    NaN
# 19           NaN     9   328698                kate    NaN
# 20           NaN    18    42046             aunibe7    NaN
# 21       average     5     4905             dputvin    NaN
# 22           NaN     7   133370       allison.leahy    NaN
# 23       average     5   990166            Michelle    NaN
# 24           NaN    18   966536          mandamay89    NaN
# 25           NaN     3   595658          crazyxme05    NaN
# 26          wide    30   585033           lzamorarn    NaN
# 27           NaN     9   129669            mmmjulie    NaN
# 28           NaN    30   884093            danielle    NaN
# 29           NaN    30    78371           Stephanie    NaN
# ...          ...   ...      ...                 ...    ...
# 82760        NaN    12   392328         kochkrystal    NaN
# 82761        NaN     4   357068     melissalehtonen    NaN
# 82762        NaN     8   465791           shara2179    NaN
# 82763     narrow     8   747277          j.pastor19    NaN
# 82764        NaN     4   475911               Hufsa    NaN
# 82765        NaN     8   864507   morrison.marianne    NaN
# 82766        NaN     8    33248      dana_johnson_1    NaN
# 82767    average    12   410366          hilaryjean    NaN
# 82768        NaN     4   918027           Elizabeth    NaN
# 82769        NaN    12   477259       allana.melody    NaN
# 82770        NaN    12   768236               Meshe    NaN
# 82771    average     8   975516                 Kat    NaN
# 82772        NaN     4    59264                sara    NaN
# 82773        NaN    12    26873                Bron    NaN
# 82774        NaN     4   235132       amberlaturner    NaN
# 82775    average    12   808373             beezy13    NaN
# 82776        NaN     8   548684            Danielle    NaN
# 82777        NaN     8   236365           spoons_82    NaN
# 82778        NaN    12   470252         mccoysarahe    NaN
# 82779    average    12   370303            lmoore81    NaN
# 82780        NaN    12   417852          ollylollie    NaN
# 82781        NaN    12    11806           charlotte    NaN
# 82782        NaN     8   972740              Maayan    NaN
# 82783        NaN     4   432480            helenag9    NaN
# 82784    average     4   317420           ciwheeles    NaN
# 82785    average     8   727820            Jennifer    NaN
# 82786        NaN    12   197040               Kelli    NaN
# 82787        NaN    12   102493            elacount    NaN
# 82788        NaN    12   756491        jennaklinner    NaN
# 82789        NaN     4    78305     maireadsteadman    NaN
#
# [82790 rows x 18 columns]

# %%
Trialdf = df[['item_id','quality','user_name']]
Trialdf
#dataframe for what matters; ratings, quality, items
# Out:
#        item_id  quality           user_name
# 0       123373      5.0               Emily
# 1       123373      3.0    sydneybraden2001
# 2       123373      2.0               Ugggh
# 3       123373      5.0        alexmeyer626
# 4       123373      5.0          dberrones1
# 5       123373      5.0         Doreenajane
# 6       123373      1.0         barbiejenks
# 7       123373      5.0           brettloie
# 8       123373      4.0      francescaviola
# 9       123373      5.0        laurenpolzin
# 10      123373      4.0            micorson
# 11      123373      5.0             tera.oh
# 12      123373      5.0            kmj11492
# 13      123373      4.0  katherineoliviaman
# 14      123373      5.0            stacy233
# 15      123373      4.0         tamera.cole
# 16      123373      5.0         choircorgis
# 17      123373      4.0               Megan
# 18      123373      4.0               Carol
# 19      123373      1.0                kate
# 20      123373      5.0             aunibe7
# 21      123373      5.0             dputvin
# 22      123373      4.0       allison.leahy
# 23      123373      5.0            Michelle
# 24      123373      4.0          mandamay89
# 25      123373      5.0          crazyxme05
# 26      123373      5.0           lzamorarn
# 27      123373      5.0            mmmjulie
# 28      123373      5.0            danielle
# 29      123373      4.0           Stephanie
# ...        ...      ...                 ...
# 82760   807722      5.0         kochkrystal
# 82761   807722      5.0     melissalehtonen
# 82762   807722      5.0           shara2179
# 82763   807722      5.0          j.pastor19
# 82764   807722      5.0               Hufsa
# 82765   807722      4.0   morrison.marianne
# 82766   807722      5.0      dana_johnson_1
# 82767   807722      2.0          hilaryjean
# 82768   807722      3.0           Elizabeth
# 82769   807722      3.0       allana.melody
# 82770   807722      5.0               Meshe
# 82771   807722      4.0                 Kat
# 82772   807722      5.0                sara
# 82773   807722      5.0                Bron
# 82774   807722      4.0       amberlaturner
# 82775   807722      4.0             beezy13
# 82776   807722      5.0            Danielle
# 82777   807722      4.0           spoons_82
# 82778   807722      5.0         mccoysarahe
# 82779   807722      4.0            lmoore81
# 82780   807722      4.0          ollylollie
# 82781   807722      5.0           charlotte
# 82782   807722      3.0              Maayan
# 82783   807722      5.0            helenag9
# 82784   807722      3.0           ciwheeles
# 82785   807722      4.0            Jennifer
# 82786   807722      5.0               Kelli
# 82787   807722      5.0            elacount
# 82788   807722      4.0        jennaklinner
# 82789   807722      4.0     maireadsteadman
#
# [82790 rows x 3 columns]

# %%
Trialdf.isnull().sum()
# Out:
# item_id       0
# quality      68
# user_name     0
# dtype: int64

# %%
Trialdf = Trialdf[np.isfinite(Trialdf['quality'])]
Trialdf.isnull().sum()
#Removing the 68 NAN rows in quality
# Out:
# item_id      0
# quality      0
# user_name    0
# dtype: int64

# %%
Unique_Users = Trialdf.user_name.unique()
Unique_Users
#Made List containing all individual users 
#Done
# Out:
# array(['Emily', 'sydneybraden2001', 'Ugggh', ..., 'beezy13', 'Maayan',
#        'maireadsteadman'], dtype=object)

# %%
List_of_Users_And_NumOfPurchases = Trialdf.groupby('user_name').count().item_id
UserNumBought_List = np.array(List_of_Users_And_NumOfPurchases)
UserNumBought_List
#32,3999 unique user names, with the number of purchases for each user, everyone rated every item they purchased
#How much Each Person is Buying
#Done
# Out:
# array([1, 1, 1, ..., 5, 1, 1])

# %%
UserNumBought_List.mean()
#Average amount of Items bought by a person
# Out:
# 2.5532269514491186

# %%
List_of_Items_And_NumOfUsers = Trialdf.groupby('item_id').count().user_name
ItemNumBought_List = np.array(List_of_Items_And_NumOfUsers)
ItemNumBought_List
#How much Each Item is being Bought
#Done
# Out:
# array([ 53,  14, 172, ...,  65,  24,  47])

# %%
ItemNumBought_List.mean()
#Average amount of times an item is bought
# Out:
# 60.11773255813954

# %%
Unique_Items = Trialdf.item_id.unique()
Unique_Items
#List of all individual items
#Done
# Out:
# array([123373, 124024, 124124, ..., 807252, 807384, 807722])

# %%
print(Trialdf.loc[Trialdf['user_name'].isin(['ana'])])
#Looking at an individual's ('ana') purchases and ratings
# Out:
#        item_id  quality user_name  List_of_Ratings
# 2918    136482      5.0       ana              5.0
# 29986   404557      4.0       ana              4.0
# 41785   454030      5.0       ana              5.0
# 44657   484879      4.0       ana              4.0
# 48145   519836      3.0       ana              3.0
# 77136   765620      3.0       ana              3.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import scipy
from scipy import stats
sns.pairplot(Trialdf)

# %%
sns.distplot(Trialdf['quality'])
#Most customers seem to be happier with their purchases than being disappointed

# %%
sns.distplot(ItemNumBought_List)
#Clearly shows how majority of items were bought less than 50 times

# %%
Trialdf.describe()
# Out:
#              item_id       quality  List_of_Ratings
# count   82722.000000  82722.000000     82722.000000
# mean   469317.322756      3.949058         3.949058
# std    213996.309012      0.992783         0.992783
# min    123373.000000      1.000000         1.000000
# 25%    314980.000000      3.000000         3.000000
# 50%    454030.000000      4.000000         4.000000
# 75%    658440.000000      5.000000         5.000000
# max    807722.000000      5.000000         5.000000

# %%
#Read in values as Surprise dataset
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(Trialdf[['user_name', 'item_id', 'quality']], reader)

# %%
trainset, testset = train_test_split(data,test_size=0.2)

# %%
#Trying to make List of all Users in the Test Set
testset
# Out:
# [('Rachel', 806856, 5.0),
#  ('andreajenels', 484879, 2.0),
#  ('sophie.b.lebel', 175771, 5.0),
#  ('Hannah', 417269, 5.0),
#  ('cnasui12', 171740, 4.0),
#  ('drashtahip3588', 722362, 4.0),
#  ('sabrinazappa', 416942, 5.0),
#  ('Kebayagirl', 165525, 3.0),
#  ('lilpunkyy', 550103, 3.0),
#  ('Heather', 126885, 4.0),
#  ('Kelly', 400541, 5.0),
#  ('Sarah', 412737, 3.0),
#  ('bethlassiter76', 425631, 3.0),
#  ('Annie', 604607, 4.0),
#  ('aruggieri415', 726492, 3.0),
#  ('Maddy', 712030, 3.0),
#  ('Anne', 668696, 3.0),
#  ('g.michelle.perez', 407134, 5.0),
#  ('zinomura', 407574, 3.0),
#  ('Brandi', 765620, 5.0),
#  ('gmorton23', 659701, 5.0),
#  ('Katy', 401773, 5.0),
#  ('kmasick', 391519, 4.0),
#  ('Lucy', 486643, 5.0),
#  ('Jogita', 391519, 5.0),
#  ('Elisa', 630114, 3.0),
#  ('johnna_73', 637931, 5.0),
#  ('Leanne', 539980, 5.0),
#  ('lapierce50', 581432, 3.0),
#  ('averysteele1', 175771, 4.0),
#  ('Deb', 647235, 3.0),
#  ('alisan.amrhein', 165525, 1.0),
#  ('kraney0223', 152702, 5.0),
#  ('AGG1', 269063, 5.0),
#  ('meganlaurareimer', 407134, 4.0),
#  ('susantomko', 530472, 1.0),
#  ('Joyce', 200824, 4.0),
#  ('jcrodier', 163558, 4.0),
#  ('Lauren', 768741, 3.0),
#  ('looneyaim', 146231, 3.0),
#  ('kgraibus', 484879, 5.0),
#  ('Shawn', 517055, 2.0),
#  ('Tasha', 627861, 5.0),
#  ('rubberlady', 657081, 5.0),
#  ('Andrea', 697881, 5.0),
#  ('Dee', 410934, 3.0),
#  ('pamburchard', 136482, 3.0),
#  ('ennax0r18', 404557, 3.0),
#  ('Chantelle', 719701, 5.0),
#  ('mornajackel', 806479, 3.0),
#  ('Megan', 647235, 3.0),
#  ('Bella', 752825, 3.0),
#  ('Elizabeth', 429442, 5.0),
#  ('Teanette', 402677, 5.0),
#  ('vee', 785517, 4.0),
#  ('makenab', 404229, 5.0),
#  ('beans_4_you', 633619, 5.0),
#  ('aklein00288', 715662, 4.0),
#  ('vinele', 645822, 4.0),
#  ('kimebennett', 406357, 4.0),
#  ('cariskull', 353933, 4.0),
#  ('Samantha', 647235, 4.0),
#  ('sidneybaxter1', 165525, 3.0),
#  ('manda.dyson', 411494, 2.0),
#  ('jlbowker', 765620, 3.0),
#  ('Nicole', 425631, 4.0),
#  ('Christy', 715662, 4.0),
#  ('jlpernick', 152513, 5.0),
#  ('trickett96', 412003, 5.0),
#  ('Therese', 407134, 4.0),
#  ('Andria', 167315, 4.0),
#  ('xdevanwalker', 163558, 4.0),
#  ('Estefania', 484879, 5.0),
#  ('meaghan062', 200824, 5.0),
#  ('zelda122083', 416738, 4.0),
#  ('ccjackie', 539980, 5.0),
#  ('Shannon', 397005, 5.0),
#  ('Stephanie', 492279, 5.0),
#  ('Wendy', 146231, 5.0),
#  ('kzellner', 722362, 1.0),
#  ('Natasha', 163558, 3.0),
#  ('Brandie', 647235, 5.0),
#  ('kesia.kvill', 391519, 5.0),
#  ('Tonya', 657081, 3.0),
#  ('vanessacathy', 486643, 3.0),
#  ('Mardi', 414857, 5.0),
#  ('lauradarinagriffin', 397005, 5.0),
#  ('onthe2starr', 136482, 5.0),
#  ('Marga', 412003, 2.0),
#  ('meganakemp', 503595, 2.0),
#  ('cmenascod', 412737, 5.0),
#  ('Jordan', 397005, 3.0),
#  ('danielledanti4', 400486, 5.0),
#  ('dmgardner14', 397005, 4.0),
#  ('hritter0', 654585, 2.0),
#  ('Carrie', 181718, 3.0),
#  ('rustamyn', 520958, 4.0),
#  ('Kristin', 645822, 3.0),
#  ('ashleyvantrease', 668696, 5.0),
#  ('Rebecca', 545232, 5.0),
#  ('lesbellestulipes', 407044, 3.0),
#  ('galassonatalie', 391519, 5.0),
#  ('Ashley', 130424, 5.0),
#  ('berrones.daniela', 719701, 5.0),
#  ('Kristal', 539980, 4.0),
#  ('breschra91486', 387118, 5.0),
#  ('Erica', 539980, 5.0),
#  ('c_draffin', 397005, 3.0),
#  ('jillcridenour', 648310, 3.0),
#  ('bowsher7', 752825, 4.0),
#  ('chwalc21', 427041, 5.0),
#  ('sarmes16', 756722, 1.0),
#  ('tara.husband.evans', 406357, 4.0),
#  ('mlupher', 757731, 4.0),
#  ('lisa.sayre', 168387, 3.0),
#  ('eareisus', 404557, 5.0),
#  ('Taylor', 778687, 4.0),
#  ('lusiyi', 723977, 4.0),
#  ('sabeyer', 621405, 4.0),
#  ('Alexandra', 539980, 4.0),
#  ('Denise', 806479, 5.0),
#  ('Allison', 391519, 4.0),
#  ('chelsea.jones202', 792006, 5.0),
#  ('Allison', 163558, 5.0),
#  ('Kieu', 169727, 1.0),
#  ('ktabrooks', 152513, 4.0),
#  ('singsong639', 125442, 5.0),
#  ('wendyjmcpherson', 200824, 5.0),
#  ('cseese', 656645, 2.0),
#  ('bluebegonia45', 136482, 4.0),
#  ('Brandy', 338596, 4.0),
#  ('lillianfaithdove', 410934, 4.0),
#  ('Allison', 492279, 4.0),
#  ('hsabel', 650890, 5.0),
#  ('judithbrown43', 645085, 5.0),
#  ('Katharine', 760113, 4.0),
#  ('dsk309', 520945, 4.0),
#  ('maryannedyer', 175771, 3.0),
#  ('sk88ks5', 423572, 5.0),
#  ('javalos0287', 129268, 4.0),
#  ('Sanday', 668696, 4.0),
#  ('jbradford14', 414857, 5.0),
#  ('Ciarra', 397005, 5.0),
#  ('rhiannon.a', 164659, 1.0),
#  ('kuahine.sands', 659701, 5.0),
#  ('collettemarisa262', 781127, 4.0),
#  ('Marie', 478481, 5.0),
#  ('Josephine', 165525, 3.0),
#  ('dogwithbooks', 521470, 4.0),
#  ('jessi.r.cowart', 697835, 5.0),
#  ('sheabbjordan', 715662, 4.0),
#  ('Steph', 125442, 5.0),
#  ('dukie1199', 151045, 4.0),
#  ('Kristen', 757731, 4.0),
#  ('foxysno_bunny', 412737, 3.0),
#  ('ericka132', 539980, 3.0),
#  ('Rai', 165525, 3.0),
#  ('Sarah', 697835, 4.0),
#  ('Kara', 712030, 5.0),
#  ('Denise', 785517, 5.0),
#  ('Abree', 126885, 3.0),
#  ('sh_riek', 657242, 3.0),
#  ('Jenny', 210299, 3.0),
#  ('rachel.arends', 379083, 5.0),
#  ('nalopez13', 478481, 3.0),
#  ('Renee', 806856, 5.0),
#  ('donnabee20', 660757, 5.0),
#  ('Amanda', 633619, 3.0),
#  ('jackiewilber12', 152513, 4.0),
#  ('Erin', 125442, 5.0),
#  ('Antoinette', 699784, 5.0),
#  ('cmgnemmi', 200824, 4.0),
#  ('Allie', 343819, 4.0),
#  ('eve.c.adams', 407044, 2.0),
#  ('Amy', 136482, 3.0),
#  ('Tamara', 486643, 4.0),
#  ('Megan', 147714, 5.0),
#  ('continuouslyme', 668696, 4.0),
#  ('s.essentialpolarity', 269063, 4.0),
#  ('ertl.alli', 621405, 5.0),
#  ('Caitlin', 707014, 5.0),
#  ('lizadviento', 400541, 5.0),
#  ('Laura', 462796, 4.0),
#  ('starry.cucumber', 486643, 4.0),
#  ('ariel.d.craig', 773957, 5.0),
#  ('nicolebirkett', 406357, 4.0),
#  ('nrlsrm', 723977, 4.0),
#  ('Nicole', 391519, 4.0),
#  ('Jessica', 416738, 4.0),
#  ('rizzorox01', 422651, 5.0),
#  ('crystalkaren', 397005, 5.0),
#  ('apapp216', 657242, 1.0),
#  ('kristen.goodpaster', 401773, 5.0),
#  ('allicat12', 661775, 5.0),
#  ('lgrienei', 712030, 4.0),
#  ('M?lanie', 175771, 4.0),
#  ('Madison', 657081, 4.0),
#  ('Erin', 314980, 3.0),
#  ('ctinahernandz', 125442, 4.0),
#  ('Caitlin', 757242, 2.0),
#  ('mfromie', 658440, 5.0),
#  ('breslinkelly', 749759, 2.0),
#  ('carob323', 146231, 3.0),
#  ('Angelica', 502359, 3.0),
#  ('nurse_alexandra', 340881, 5.0),
#  ('lynnebk', 416738, 5.0),
#  ('Sarah', 169727, 4.0),
#  ('atemprah', 482795, 5.0),
#  ('Joi', 805172, 5.0),
#  ('heatherqhundley', 404229, 4.0),
#  ('Erin', 486643, 3.0),
#  ('ruthiemn', 454030, 4.0),
#  ('ashleypdxck', 752094, 5.0),
#  ('Undisclosed', 139838, 3.0),
#  ('Jenelle', 410934, 3.0),
#  ('stephjurusz', 152513, 4.0),
#  ('hd_osburn', 550103, 3.0),
#  ('Shana', 719701, 3.0),
#  ('mandamay89', 655211, 4.0),
#  ('ptwiddy', 645822, 4.0),
#  ('Kati', 151045, 5.0),
#  ('laurenmormino92', 726492, 2.0),
#  ('janescm', 715662, 4.0),
#  ('Laura', 412737, 4.0),
#  ('cle914', 412737, 3.0),
#  ('Shoshana', 406357, 5.0),
#  ('thepinkglittergirl', 298256, 5.0),
#  ('Audrey', 175771, 4.0),
#  ('snoopylvr818', 756073, 5.0),
#  ('isabella_forshee', 414247, 3.0),
#  ('smparsons13', 165525, 3.0),
#  ('dublin597', 427041, 5.0),
#  ('mizg21077', 477210, 5.0),
#  ('Mandy', 397005, 4.0),
#  ('mollie.e.finkelberg', 136482, 5.0),
#  ('kaylee.meyer', 165525, 5.0),
#  ('taylor__7421', 409228, 5.0),
#  ('Amanda', 722362, 5.0),
#  ('eelime2185', 407574, 3.0),
#  ('vskubal', 780724, 3.0),
#  ('ellychan0610', 407134, 3.0),
#  ('hollaleigh', 152702, 3.0),
#  ('kacie', 407044, 3.0),
#  ('christi_lynn', 604607, 3.0),
#  ('midget92', 697835, 5.0),
#  ('laurenfvanderzee', 792842, 4.0),
#  ('lauramstamp', 410263, 4.0),
#  ('Shannon', 755526, 2.0),
#  ('kreklau', 604607, 5.0),
#  ('graebutton', 699784, 3.0),
#  ('bkinga9', 366306, 4.0),
#  ('karla', 484879, 2.0),
#  ('rachel_g90', 200824, 3.0),
#  ('ErinP', 503264, 5.0),
#  ('Worlanyo', 400541, 5.0),
#  ('Sharnell', 645822, 4.0),
#  ('lioness_grrl', 129268, 4.0),
#  ('wumba28', 655211, 4.0),
#  ('fish.n.chips1001', 760581, 4.0),
#  ('Emily', 131951, 5.0),
#  ('cheryl.paez', 519836, 3.0),
#  ('Francesca', 486643, 5.0),
#  ('Rhiannon', 656645, 5.0),
#  ('j.salahub', 806479, 5.0),
#  ('melanie', 167315, 3.0),
#  ('collay23', 654585, 3.0),
#  ('megankgross', 161514, 2.0),
#  ('megankgross', 161789, 4.0),
#  ('Becca', 130225, 4.0),
#  ('Danielle', 621405, 5.0),
#  ('jmcproductions', 416942, 5.0),
#  ('marierolving', 756073, 3.0),
#  ('Caroline', 539980, 3.0),
#  ('Sara', 404557, 3.0),
#  ('Sarah', 338596, 3.0),
#  ('kezialiu', 699784, 4.0),
#  ('carignan.kim', 781127, 4.0),
#  ('arkley.laura', 756722, 5.0),
#  ('Caitlin', 402677, 3.0),
#  ('kdekon82', 146231, 4.0),
#  ('ntfatal', 165525, 2.0),
#  ('moreenroh', 165716, 4.0),
#  ('adragon1488', 407574, 4.0),
#  ('kathrynkotz', 469939, 5.0),
#  ('yvette', 780724, 5.0),
#  ('Christina', 397005, 5.0),
#  ('ranjani3', 153494, 3.0),
#  ('Jennifer', 429442, 5.0),
#  ('Lindsey', 152513, 4.0),
#  ('Lisa', 712030, 3.0),
#  ('mgklose', 163758, 5.0),
#  ('Jessica', 570378, 2.0),
#  ('meredith', 125442, 4.0),
#  ('Tien', 152702, 5.0),
#  ('jallen052', 454764, 5.0),
#  ('rmkearney1421', 429442, 4.0),
#  ('Jade', 727560, 3.0),
#  ('Mandy', 391519, 4.0),
#  ('Kelly', 756073, 3.0),
#  ('Andrea', 647030, 5.0),
#  ('ancilla.rose', 539980, 4.0),
#  ('cshawler', 697835, 5.0),
#  ('nh53307', 167315, 3.0),
#  ('sarastar43', 152702, 4.0),
#  ('diabadass89', 481011, 4.0),
#  ('jennifer', 604607, 5.0),
#  ('sportsfanatic4', 474002, 4.0),
#  ('Sarah', 416738, 2.0),
#  ('lindyrae', 407134, 2.0),
#  ('Suzanne', 169727, 4.0),
#  ('Erin', 414857, 4.0),
#  ('anschaef', 384207, 2.0),
#  ('jessicanesbitsoprano', 640171, 5.0),
#  ('Lauren', 445254, 5.0),
#  ('Kris', 494869, 5.0),
#  ('Lily', 360255, 5.0),
#  ('Ashley', 445254, 5.0),
#  ('amy0002', 412737, 3.0),
#  ('Kate', 161592, 5.0),
#  ('Lauren', 668696, 3.0),
#  ('lucy', 125442, 5.0),
#  ('Mealz7', 805642, 5.0),
#  ('lheisick', 152702, 4.0),
#  ('jillavive', 756722, 2.0),
#  ('carole.lem', 604607, 4.0),
#  ('brown_belleza', 161592, 5.0),
#  ('alw285', 768644, 5.0),
#  ('Lyndsey', 404229, 5.0),
#  ('hgibson', 693560, 5.0),
#  ('kes39', 165525, 3.0),
#  ('bethyanne', 750256, 3.0),
#  ('mmrthesen1', 397005, 4.0),
#  ('leisliegutierrez27', 400541, 5.0),
#  ('adrianmanahan82', 486643, 4.0),
#  ('ekm1011', 693560, 3.0),
#  ('galassonatalie', 515644, 3.0),
#  ('Stacy', 404229, 4.0),
#  ('melissa.buchanan.is', 530472, 4.0),
#  ('cgelman813', 360707, 3.0),
#  ('carita41603', 125442, 4.0),
#  ('Megan', 418434, 5.0),
#  ('randiannie', 760581, 4.0),
#  ('alicialeigh26', 136482, 4.0),
#  ('Sarah', 752825, 5.0),
#  ('Lisa', 757508, 4.0),
#  ('Meghan', 697835, 4.0),
#  ('Annie', 604607, 3.0),
#  ('Jrtprods', 219785, 5.0),
#  ('amandabaum2', 757731, 4.0),
#  ('miller.hannahr', 462796, 4.0),
#  ('ashleyp098', 539980, 4.0),
#  ('sarajohnson2919', 503595, 4.0),
#  ('stephanie.s.morgan', 661169, 4.0),
#  ('gayleforcedesign', 657081, 4.0),
#  ('Carrie', 175771, 3.0),
#  ('jenniferlphillips', 507565, 4.0),
#  ('isabelle', 414857, 4.0),
#  ('achilles0524', 630114, 3.0),
#  ('Andie', 410934, 5.0),
#  ('kalopsiahenry', 298256, 3.0),
#  ('missysavage3', 647235, 5.0),
#  ('Susan', 394692, 5.0),
#  ('Megan', 697835, 4.0),
#  ('Sydney', 723977, 5.0),
#  ('fionajean13', 581432, 3.0),
#  ('j.pastor19', 604607, 4.0),
#  ('Megan', 539980, 5.0),
#  ('Brittney', 404557, 4.0),
#  ('abigailfagan', 445254, 5.0),
#  ('Rachel', 668696, 3.0),
#  ('coccinella920', 654585, 5.0),
#  ('pkieslin', 400486, 4.0),
#  ('Snowbot', 367051, 3.0),
#  ('Tany', 630114, 5.0),
#  ('Shannon', 481011, 5.0),
#  ('Lora', 445254, 5.0),
#  ('Tina', 412737, 5.0),
#  ('censly2', 663571, 3.0),
#  ('Kristina', 781127, 4.0),
#  ('Meagan', 126885, 3.0),
#  ('earlbie', 397005, 5.0),
#  ('Ayla', 753935, 4.0),
#  ('vbarrows', 397005, 3.0),
#  ('Cassie', 478481, 5.0),
#  ('kaylie.welsh', 163558, 4.0),
#  ('cjschmitz226', 161514, 4.0),
#  ('Allison', 163086, 4.0),
#  ('Grace', 427567, 2.0),
#  ('awilda8686', 723977, 4.0),
#  ('brittanylynn224', 139123, 4.0),
#  ('kakashisaya', 391519, 5.0),
#  ('you.are.not.me.26', 727560, 3.0),
#  ('Christina', 760407, 4.0),
#  ('lillieandme', 657081, 3.0),
#  ('Mary', 726492, 4.0),
#  ('jessica.toth', 314980, 5.0),
#  ('Sara', 397005, 4.0),
#  ('Haylee', 380801, 4.0),
#  ('rebeccaelizabethedonley', 777527, 5.0),
#  ('Amanda', 530472, 3.0),
#  ('Amanda', 780724, 2.0),
#  ('Katie', 539980, 2.0),
#  ('stomalesky', 668696, 4.0),
#  ('karinak120', 723977, 5.0),
#  ('Bonnie', 723977, 4.0),
#  ('miss.summer', 656645, 4.0),
#  ('Nicole', 659701, 5.0),
#  ('Jenna', 399356, 5.0),
#  ('Meagan', 210299, 4.0),
#  ('Elesia', 380801, 5.0),
#  ('shiragel', 429442, 5.0),
#  ('srthees', 338596, 4.0),
#  ('Julia', 210299, 4.0),
#  ('filgreat2010', 645822, 4.0),
#  ('Amber', 200824, 5.0),
#  ('monotron11', 693560, 5.0),
#  ('Tina', 478481, 4.0),
#  ('Sophie', 427567, 5.0),
#  ('Andrea', 161514, 5.0),
#  ('dana_louise', 699784, 3.0),
#  ('K', 645822, 1.0),
#  ('Mantis', 780724, 2.0),
#  ('Jamie', 397005, 5.0),
#  ('popp.betti', 269063, 5.0),
#  ('Melissa Alexandra', 668696, 2.0),
#  ('alyssa.franks', 781127, 4.0),
#  ('Evann', 146808, 4.0),
#  ('hcharles2010', 645822, 3.0),
#  ('kcsilber28', 397005, 5.0),
#  ('Sophia', 414857, 4.0),
#  ('April', 416738, 5.0),
#  ('cmbenjamin', 484879, 3.0),
#  ('anniecolpitts', 416942, 3.0),
#  ('ap3269', 656645, 5.0),
#  ('Natasha', 147714, 3.0),
#  ('shae', 338596, 2.0),
#  ('spinto8384', 469939, 3.0),
#  ('kaburdette', 200824, 5.0),
#  ('osyris1', 407044, 4.0),
#  ('Christine', 633619, 3.0),
#  ('Madeline', 380801, 5.0),
#  ('apapp216', 654585, 5.0),
#  ('Valerie', 414857, 5.0),
#  ('Kiah', 693560, 5.0),
#  ('Rebecca', 390319, 5.0),
#  ('Melissa', 257588, 5.0),
#  ('Jamie', 414857, 5.0),
#  ('Silence', 539980, 4.0),
#  ('hannahlmarko', 338596, 3.0),
#  ('Rilla', 539980, 5.0),
#  ('smiller0733', 507565, 5.0),
#  ('valerie.l.lindak', 391519, 3.0),
#  ('breanna.branson', 163558, 3.0),
#  ('midget92', 412737, 3.0),
#  ('Taylor', 668696, 3.0),
#  ('amberjones04', 146231, 3.0),
#  ('jsscmchl7', 210299, 2.0),
#  ('Natalie', 539980, 5.0),
#  ('anya.garrett', 175771, 4.0),
#  ('kig3188', 163558, 5.0),
#  ('Ashley', 169727, 5.0),
#  ('gracie.behre', 659701, 5.0),
#  ('michelle.madsen', 171125, 4.0),
#  ('eviretuad', 715662, 4.0),
#  ('mariescarsella', 298256, 4.0),
#  ('craigg.gould', 661775, 3.0),
#  ('freundn4', 393265, 5.0),
#  ('Fawn', 427567, 3.0),
#  ('jillmurray', 392144, 5.0),
#  ('lilycarey4', 684260, 4.0),
#  ('carsonmonicalynn', 144486, 5.0),
#  ('Beth', 668696, 4.0),
#  ('nataliejengel', 136482, 4.0),
#  ('kaylalinds', 520958, 3.0),
#  ('charlotte', 792006, 5.0),
#  ('Melissa', 719701, 2.0),
#  ('olivialothary', 756722, 5.0),
#  ('ModLover', 630114, 4.0),
#  ('pretty_eyes_fall', 414247, 3.0),
#  ('Azrianna', 645822, 3.0),
#  ('shortnurse1977', 136482, 2.0),
#  ('thebonnybirdashley', 427567, 4.0),
#  ('farahmae', 645822, 4.0),
#  ('Meghan', 399074, 3.0),
#  ('samanthahumphrey0', 661169, 4.0),
#  ('Ann', 171740, 5.0),
#  ('emily.harry', 416738, 5.0),
#  ('Audrey', 776807, 3.0),
#  ('Sheryl', 422651, 5.0),
#  ('glynnisghenderson', 645822, 3.0),
#  ('brittany.monteiro', 414857, 5.0),
#  ('Emily', 637907, 5.0),
#  ('pivogirl18', 427567, 4.0),
#  ('Hannah', 175771, 5.0),
#  ('Jade', 515644, 4.0),
#  ('Aubrey', 693560, 4.0),
#  ('Ashley', 517055, 5.0),
#  ('Phoebe', 630114, 3.0),
#  ('Martie', 643503, 4.0),
#  ('Kim', 630114, 5.0),
#  ('kaygee1988', 668696, 3.0),
#  ('Charmainne', 392144, 3.0),
#  ('Claudia', 404229, 5.0),
#  ('madeline803', 139123, 4.0),
#  ('daniellebedry', 161592, 4.0),
#  ('vausie4', 715662, 4.0),
#  ('henrykat', 391519, 5.0),
#  ('crystal.handsontherapy', 146231, 3.0),
#  ('aubrierwilson', 412003, 5.0),
#  ('rteravskis', 481011, 3.0),
#  ('catalepsky', 153494, 3.0),
#  ('lellx2rescue', 520945, 4.0),
#  ('shaun.dubreuil', 221728, 4.0),
#  ('wright.shawna', 175771, 4.0),
#  ('fletchroot', 647551, 5.0),
#  ('Kaili', 391519, 2.0),
#  ('GracieLou', 486643, 4.0),
#  ('Asenath', 397005, 4.0),
#  ('tonksy', 153494, 3.0),
#  ('Mia', 697835, 4.0),
#  ('crysdollins', 757731, 3.0),
#  ('intoxikaty', 165716, 5.0),
#  ('bwisekal', 125442, 4.0),
#  ('Jasmin', 146231, 5.0),
#  ('kleotide', 652823, 3.0),
#  ('Breanna', 757731, 5.0),
#  ('Bridget', 656645, 5.0),
#  ('manythemiles09', 129268, 3.0),
#  ('cwakefield1026', 404229, 5.0),
#  ('Kari', 546664, 2.0),
#  ('Sara', 146231, 5.0),
#  ('kendra.tillis', 144486, 3.0),
#  ('noodlehair1528', 200824, 5.0),
#  ('xo.alycia.ox', 633619, 2.0),
#  ('Sinead', 693560, 5.0),
#  ('kristirae1', 338596, 4.0),
#  ('Alison', 604607, 3.0),
#  ('Sarah', 397005, 5.0),
#  ('Kiara', 454030, 5.0),
#  ('Jamie', 806856, 4.0),
#  ('julie', 416942, 5.0),
#  ('serenityparkjerangle', 486643, 3.0),
#  ('ashleigh_j_90', 633619, 5.0),
#  ('Jordan', 697835, 4.0),
#  ('jillian', 693560, 3.0),
#  ('katie2013davis', 633619, 5.0),
#  ('TheBlueSwan', 630114, 5.0),
#  ('kristi.cheshire', 657242, 3.0),
#  ('Veronica', 722362, 4.0),
#  ('jennaklinner', 144486, 4.0),
#  ('Colette', 647551, 5.0),
#  ('dianneelainehummel', 409228, 4.0),
#  ('diannafour', 175771, 5.0),
#  ('narnarigray', 417269, 5.0),
#  ('tnarayanan2', 478122, 1.0),
#  ('kimberdoll2002', 167315, 2.0),
#  ('specimenq5', 394692, 5.0),
#  ('Rebecca', 693560, 3.0),
#  ('beckajayne21', 520945, 5.0),
#  ('jordanvandewinckel', 806856, 5.0),
#  ('ecsavageau', 454764, 4.0),
#  ('hayleyjaneschwartz', 486643, 3.0),
#  ('tammynich', 151045, 4.0),
#  ('slawson017', 470071, 5.0),
#  ('kaseychamp', 723977, 5.0),
#  ('glockard13', 714723, 5.0),
#  ('tenshirei', 753429, 4.0),
#  ('nijs11', 656645, 4.0),
#  ('sarahgail.mullins', 530472, 3.0),
#  ('rstrom90', 545232, 2.0),
#  ('reje98', 799325, 3.0),
#  ('Veronica', 484879, 5.0),
#  ('Mellisa', 380801, 4.0),
#  ('camturt', 338596, 5.0),
#  ('Cara', 806479, 5.0),
#  ('Erica', 756073, 3.0),
#  ('Megan', 454030, 5.0),
#  ('claire', 668696, 3.0),
#  ('sajwest', 407044, 5.0),
#  ('Ashley', 758539, 3.0),
#  ('Grace', 696347, 2.0),
#  ('nedla', 298256, 5.0),
#  ('AnneKatrin', 397642, 4.0),
#  ('Statistics', 659799, 4.0),
#  ('Leah', 402677, 5.0),
#  ('krystal', 416942, 5.0),
#  ('saclioness', 129268, 5.0),
#  ('richantics', 663571, 5.0),
#  ('kjarvis222', 407134, 2.0),
#  ('Reesa', 697835, 5.0),
#  ('tinavanwinkle', 445254, 4.0),
#  ('Claire', 154411, 3.0),
#  ('amber', 757731, 5.0),
#  ('amebrew', 228276, 5.0),
#  ('Sarah', 179339, 4.0),
#  ('kendallmcgowan', 643503, 3.0),
#  ('qxyhrox', 756073, 4.0),
#  ('Martha', 765620, 5.0),
#  ('amiegossett', 411494, 5.0),
#  ('stephanielynngray', 130424, 4.0),
#  ('lbkotler', 397005, 3.0),
#  ('Lindsay', 394692, 4.0),
#  ('mjwedding326', 161592, 3.0),
#  ('Tracey', 171579, 5.0),
#  ('anna_rowland', 468050, 3.0),
#  ('abigailjyoung', 604607, 3.0),
#  ('omahedy', 621405, 3.0),
#  ('sdemane34', 397005, 4.0),
#  ('carolyn.kuzminski', 200824, 5.0),
#  ('Nichelle', 314980, 5.0),
#  ('Emily', 630114, 5.0),
#  ('Meghan', 621405, 3.0),
#  ('Kimberly', 659701, 3.0),
#  ('Judy', 175771, 4.0),
#  ('jackiebyc8023', 374083, 4.0),
#  ('ladycyg', 753935, 5.0),
#  ('Samantha', 427567, 3.0),
#  ('j_crae', 657242, 4.0),
#  ('Heidi', 391519, 3.0),
#  ('Paula', 165525, 4.0),
#  ('Sheryl', 126560, 5.0),
#  ('Gwen', 715662, 4.0),
#  ('michelle.brown872', 269063, 4.0),
#  ('jessica.marie.cantrell', 657242, 2.0),
#  ('wine.nora', 657242, 5.0),
#  ('lucycoco12', 793274, 5.0),
#  ('Michele', 752094, 4.0),
#  ('Shayda', 752825, 5.0),
#  ('Lord', 165525, 4.0),
#  ('leslie_karol', 380801, 5.0),
#  ('Emily', 152513, 4.0),
#  ('arlenebiglin', 175771, 2.0),
#  ('Jody', 604607, 5.0),
#  ('norozco21', 269063, 5.0),
#  ('trent1at', 407134, 3.0),
#  ('ferristhefurious', 165716, 3.0),
#  ('kristenbellehelton', 757731, 5.0),
#  ('samantha.lee.wallace', 340237, 4.0),
#  ('Natalie', 340237, 5.0),
#  ('josefine.jehlbo', 539980, 5.0),
#  ('Jenna', 298256, 5.0),
#  ('Kelly', 412737, 4.0),
#  ('etwfisher', 757242, 4.0),
#  ('Kristine', 454030, 5.0),
#  ('itslucybitch', 645822, 3.0),
#  ('agalick', 175771, 4.0),
#  ('kelli.sobolik', 146231, 5.0),
#  ('lianchilds', 520958, 5.0),
#  ('Andrea', 806856, 5.0),
#  ('Laura', 768644, 5.0),
#  ('ledgeorge123', 645822, 5.0),
#  ('Shaynah', 419547, 3.0),
#  ('Saori', 598899, 5.0),
#  ('Vanessa', 517055, 5.0),
#  ('robertany2000', 507565, 4.0),
#  ('julietoneal', 412003, 5.0),
#  ('Adrienne', 655211, 3.0),
#  ('lexa1899', 407134, 5.0),
#  ('mikhel.kushner', 412737, 3.0),
#  ('Laurel', 655211, 4.0),
#  ('kccreationstudio', 129268, 5.0),
#  ('Tenacious', 147714, 3.0),
#  ('Tamara', 129268, 4.0),
#  ('silverninjax', 697835, 5.0),
#  ('alexander.sonya3', 219785, 5.0),
#  ('stephaniestarling85', 752094, 5.0),
#  ('Amanda', 668696, 5.0),
#  ('Anne', 210299, 5.0),
#  ('gowdy.sarah', 756722, 5.0),
#  ('em4245', 412737, 4.0),
#  ('Debbie', 152513, 5.0),
#  ('airykah1313', 633619, 3.0),
#  ('klw103185', 648310, 3.0),
#  ('Kate', 414857, 3.0),
#  ('Stephanie', 125442, 4.0),
#  ('Sarah', 340237, 5.0),
#  ('jvierra', 657242, 3.0),
#  ('becker_ashley05', 338596, 3.0),
#  ('christinejanelaudler', 760407, 5.0),
#  ('hollincalloway', 337420, 4.0),
#  ('Tianna', 661775, 4.0),
#  ('taylorannetattoos', 693560, 4.0),
#  ('claire.a.a.walters', 445254, 5.0),
#  ('lscharfetter', 502359, 5.0),
#  ('katharine.depew', 546664, 4.0),
#  ('aprilm524', 155572, 5.0),
#  ('kristine', 806856, 5.0),
#  ('valerie.k.cooke', 210299, 3.0),
#  ('Jennifer', 397005, 5.0),
#  ('Meaghan', 404229, 4.0),
#  ('beckispiering', 416942, 5.0),
#  ('carynneburnett', 637907, 4.0),
#  ('Vivian', 519836, 3.0),
#  ('linfenny', 456078, 5.0),
#  ('leah.hatmaker', 169727, 2.0),
#  ('Kristine', 645822, 5.0),
#  ('Madeline', 397005, 5.0),
#  ('Lauren', 410934, 4.0),
#  ('Stephanie', 621405, 5.0),
#  ('mclayton3663', 398317, 3.0),
#  ('Melissa', 780724, 5.0),
#  ('Rebecca', 200824, 4.0),
#  ('freckles815', 337420, 3.0),
#  ('Lisa', 130424, 4.0),
#  ('rosslin78', 169727, 5.0),
#  ('bronwynn.ollington', 407134, 4.0),
#  ('Jessica', 643503, 5.0),
#  ('rs.freshnsassy98', 221693, 5.0),
#  ('laurenconeal', 314980, 3.0),
#  ('Kat', 723977, 2.0),
#  ('Angela', 726492, 3.0),
#  ('filgreat2010', 668696, 5.0),
#  ('lidia.aurora01', 391519, 5.0),
#  ('Mina', 628366, 3.0),
#  ('hesteveshe', 757731, 5.0),
#  ('Christine', 407134, 5.0),
#  ('Sunita', 520958, 5.0),
#  ('steener239', 806479, 4.0),
#  ('Lauren', 656172, 4.0),
#  ('Melanie', 391519, 5.0),
#  ('Christine', 146808, 5.0),
#  ('knowlton.kristina', 630114, 5.0),
#  ('Lauren', 756722, 3.0),
#  ('twosquid', 165525, 2.0),
#  ('cktheisen07', 407134, 5.0),
#  ('Melissa', 757731, 4.0),
#  ('Alicia', 668696, 4.0),
#  ('Natalie', 397005, 3.0),
#  ('tiffo373', 445254, 4.0),
#  ('alaska', 152513, 3.0),
#  ('sheridan.lacey89', 753935, 3.0),
#  ('brittbyers', 427041, 4.0),
#  ('Alison', 165525, 3.0),
#  ('lauraenglish11', 228276, 3.0),
#  ('Brittiny', 419547, 4.0),
#  ('Saundra', 397005, 5.0),
#  ('ahalfacre85', 154411, 4.0),
#  ('effulgenta', 338596, 5.0),
#  ('Valerie', 152513, 5.0),
#  ('sarah.varrichio', 175771, 5.0),
#  ('hillary.voris', 697835, 4.0),
#  ('laurenem0723', 146808, 5.0),
#  ('Raquel', 204815, 3.0),
#  ('Katie', 469939, 5.0),
#  ('skillury', 481011, 2.0),
#  ('shelbyjeffcoat', 387118, 3.0),
#  ('caitlinpereiras', 707014, 4.0),
#  ('ashleyhuckabee', 621405, 3.0),
#  ('karliebialas', 397642, 4.0),
#  ('jnbaker7713', 407134, 4.0),
#  ('sweetie', 639328, 3.0),
#  ('earthchild29', 407134, 5.0),
#  ('vic7', 793274, 3.0),
#  ('amgore83', 481011, 5.0),
#  ('Shannon', 655211, 3.0),
#  ('haleyrae8', 793274, 3.0),
#  ('Laticia', 539980, 5.0),
#  ('Melissa', 416942, 5.0),
#  ('alexvonglahn', 519836, 2.0),
#  ('hlnicholson', 719701, 4.0),
#  ('sdaviess', 338596, 3.0),
#  ('Britni', 693560, 5.0),
#  ('just5lemons', 391519, 5.0),
#  ('arcaughron', 780724, 3.0),
#  ('Dolly', 693560, 3.0),
#  ('briden_87', 721565, 5.0),
#  ('Erica', 539980, 3.0),
#  ('Bobbie', 401773, 3.0),
#  ('shani.gentry', 806479, 4.0),
#  ('Jennifer', 658440, 5.0),
#  ('nerbua', 139123, 3.0),
#  ('liberek', 410934, 4.0),
#  ('juliapurrington', 153494, 5.0),
#  ('meemo506', 688065, 5.0),
#  ('kshorten', 391519, 4.0),
#  ('ampersand.harrison', 407044, 2.0),
#  ('Meghan', 327330, 4.0),
#  ('hrcompton92', 655211, 4.0),
#  ('Sara', 520958, 4.0),
#  ('kellylsweet', 456078, 3.0),
#  ('caitlin.beath', 630114, 4.0),
#  ('lbeene.q', 124124, 4.0),
#  ('lini_91', 530472, 4.0),
#  ('Kristina', 453244, 4.0),
#  ('carla.intza', 604607, 5.0),
#  ('Areshea', 693560, 4.0),
#  ('Marisa', 645536, 4.0),
#  ('bandnerd2522', 754891, 4.0),
#  ('evelynruth', 159891, 5.0),
#  ('lacy.love', 152702, 3.0),
#  ('Chelsea', 520945, 4.0),
#  ('koppes_caitlyn', 163558, 4.0),
#  ('quadrangles', 410934, 4.0),
#  ('juanitabrasher', 462796, 4.0),
#  ('Jessica', 397005, 3.0),
#  ('Laura', 380801, 4.0),
#  ('Karin', 726492, 3.0),
#  ('lizarmanini', 171740, 4.0),
#  ('Suzy', 391519, 4.0),
#  ('Michelle', 298256, 4.0),
#  ('katie.jeanne', 756170, 5.0),
#  ('Morgan', 124124, 3.0),
#  ('kviva', 753429, 3.0),
#  ('Kelsey', 126885, 3.0),
#  ('allthingsboozy', 474002, 4.0),
#  ('Turveytops', 721565, 5.0),
#  ('Virginia', 298256, 5.0),
#  ('elexak', 793274, 3.0),
#  ('Carolynn', 723208, 5.0),
#  ('tetrisized', 780724, 4.0),
#  ('lisa.yim', 427567, 4.0),
#  ('Lisa', 653308, 4.0),
#  ('Meg', 397005, 4.0),
#  ('susanlikesmail', 429442, 5.0),
#  ('Bethany', 757731, 5.0),
#  ('dkvibbert', 469939, 3.0),
#  ('Sarah', 153494, 5.0),
#  ('Emily', 245855, 5.0),
#  ('percimachu', 776807, 4.0),
#  ('Jess', 757242, 4.0),
#  ('lipiva', 161592, 5.0),
#  ('deirdrexmac', 682698, 4.0),
#  ('geneedl14', 750256, 4.0),
#  ('ndesilets', 792842, 3.0),
#  ('Jillian', 161592, 4.0),
#  ('JJ', 668696, 5.0),
#  ('Molly', 125442, 5.0),
#  ('liljoeymac', 391519, 4.0),
#  ('bek.lamb', 478481, 3.0),
#  ('Jill', 175771, 3.0),
#  ('Angie', 726492, 4.0),
#  ('laura.hayese', 668696, 5.0),
#  ('fultonva', 126885, 5.0),
#  ('josianneattaque', 416738, 4.0),
#  ('kaela.plyler', 661775, 1.0),
#  ('natalie_terry', 520945, 3.0),
#  ('Paige', 643503, 3.0),
#  ('Linds', 545871, 4.0),
#  ('Deanna', 175771, 4.0),
#  ('Shelly', 397005, 3.0),
#  ('loweshop420', 657242, 3.0),
#  ('martini4me27', 401773, 3.0),
#  ('csuovanen', 407134, 3.0),
#  ('Lisa', 427567, 5.0),
#  ('stephanie.bixler', 397642, 5.0),
#  ('susang', 137040, 5.0),
#  ('Dakota', 621405, 3.0),
#  ('lisathio', 124124, 5.0),
#  ('dineika.chan', 654585, 5.0),
#  ('andyk29', 806856, 4.0),
#  ('murphhel', 416738, 3.0),
#  ('amberviolets96', 392144, 5.0),
#  ('maureenchallacombe', 155572, 5.0),
#  ('Angela', 175771, 5.0),
#  ('breannascalo', 427567, 3.0),
#  ('papercannondesigns', 484879, 4.0),
#  ('klkellick', 668696, 4.0),
#  ('saramatheny07', 425631, 3.0),
#  ('bastet11190', 768242, 4.0),
#  ('Marissa', 757731, 4.0),
#  ('priyanka.mis', 407134, 1.0),
#  ('Kelly', 807722, 3.0),
#  ('Sarah', 698964, 4.0),
#  ('petrellasn', 539980, 4.0),
#  ('Jamie', 723977, 4.0),
#  ('Lorraine', 659701, 5.0),
#  ('liz.biro.07', 722362, 3.0),
#  ('CJfromtheHamlet', 763084, 5.0),
#  ('testevens83', 125442, 3.0),
#  ('emask7', 530472, 5.0),
#  ('Amy', 147714, 4.0),
#  ('sicksentries', 715662, 3.0),
#  ('Daisha', 539980, 3.0),
#  ('Hannah', 409758, 4.0),
#  ('csuperstar2', 414247, 4.0),
#  ('maxine.smith86', 397005, 5.0),
#  ('soniamason55', 165525, 3.0),
#  ('Laura', 658440, 5.0),
#  ('jana june', 658440, 4.0),
#  ('beach_babe_1237', 169727, 4.0),
#  ('Amber', 757731, 4.0),
#  ('staceytheprids', 768741, 4.0),
#  ('mollywobblesmec', 167315, 2.0),
#  ('Apple', 412003, 4.0),
#  ('Meghann', 657242, 3.0),
#  ('kavitha.nambisan', 660757, 3.0),
#  ('Jackie', 633619, 3.0),
#  ('Danny', 412737, 2.0),
#  ('monique.c.dube', 712030, 4.0),
#  ('mlhleigh', 478481, 5.0),
#  ('Bear', 738407, 5.0),
#  ('April', 654585, 4.0),
#  ('bridgetbee19', 507565, 3.0),
#  ('Christy', 153494, 4.0),
#  ('skuffy_12', 539980, 3.0),
#  ('rcmp1985', 410263, 4.0),
#  ('rebeccahansen81', 756722, 2.0),
#  ('Gracie', 146231, 2.0),
#  ('Lyndsy', 407044, 5.0),
#  ('meg_flox', 515644, 4.0),
#  ('Sarah', 129268, 4.0),
#  ('Tori', 715662, 5.0),
#  ('Nadine', 630114, 4.0),
#  ('jessiegrace', 392144, 4.0),
#  ('suzannebuehre', 171740, 5.0),
#  ('theatrebum2010', 653308, 4.0),
#  ('alixdancer', 722362, 5.0),
#  ('aidengrahame', 163758, 5.0),
#  ('girlintheblueroom', 780455, 3.0),
#  ('Kasia', 125442, 5.0),
#  ('schpippydigs', 422651, 5.0),
#  ('Toni', 380801, 5.0),
#  ('crenshawam', 668696, 5.0),
#  ('Amy', 412737, 3.0),
#  ('Andrea', 391519, 5.0),
#  ('amandalynnillustration', 503595, 3.0),
#  ('Elizabeth', 397005, 4.0),
#  ('Katharine', 654585, 4.0),
#  ('Jeanette', 715662, 4.0),
#  ('Meghann', 407044, 4.0),
#  ('Ashley', 414247, 4.0),
#  ('Gretchen', 656645, 4.0),
#  ('kellyegan10', 719701, 3.0),
#  ('Kendra', 391519, 5.0),
#  ('emevensen', 633619, 4.0),
#  ('heyymags', 210299, 3.0),
#  ('cross', 655211, 4.0),
#  ('Raquel', 712030, 3.0),
#  ('Ero', 454764, 5.0),
#  ('patriciadoll', 163558, 4.0),
#  ('patti.a.white', 638707, 4.0),
#  ('deborahmbell', 136482, 2.0),
#  ('sarahpaige623', 422651, 3.0),
#  ('sarah', 210299, 2.0),
#  ('declareurwar', 210299, 5.0),
#  ('emily.d.koch', 418434, 4.0),
#  ('Kelsey', 478481, 3.0),
#  ('jennie.m.savage', 697835, 4.0),
#  ('rhondawatson', 756073, 5.0),
#  ('geminimoon98', 404229, 4.0),
#  ('Laura', 750256, 3.0),
#  ('alyssalimberg', 404229, 4.0),
#  ('candelaria.tyler', 407044, 4.0),
#  ('ecompton', 397642, 1.0),
#  ('spdrdrvre', 125442, 4.0),
#  ('Erin', 640171, 5.0),
#  ('Indri', 806479, 3.0),
#  ('annaoufan', 712030, 5.0),
#  ('alyssaforss', 643503, 3.0),
#  ('caroline.christine95', 414857, 5.0),
#  ('lisachristensen3', 539980, 3.0),
#  ('icbmlf09', 806479, 5.0),
#  ('chastityp', 398317, 5.0),
#  ('anne.christine.williams', 397005, 4.0),
#  ('kemedina7', 661775, 3.0),
#  ('Andria', 454764, 5.0),
#  ('Jenni', 773070, 4.0),
#  ('danamooney64', 670235, 3.0),
#  ('deannalynn80', 387118, 4.0),
#  ('Jennifer', 167315, 3.0),
#  ('Desiree', 806856, 4.0),
#  ('janet.csapatuellis', 269063, 5.0),
#  ('lora.mander', 656645, 3.0),
#  ('aimee', 147714, 3.0),
#  ('smstreit', 486643, 4.0),
#  ('Jennifer', 269063, 5.0),
#  ('Melissa', 530472, 5.0),
#  ('Ally', 722362, 4.0),
#  ('jesuslover2121', 454030, 5.0),
#  ('Taylor', 404229, 4.0),
#  ('Krista', 338596, 5.0),
#  ('rachbrans', 154411, 5.0),
#  ('steph_h88', 650890, 1.0),
#  ('Jenny', 169727, 2.0),
#  ('Eliza', 507565, 3.0),
#  ('Vanessa', 402677, 3.0),
#  ('Emily', 414247, 4.0),
#  ('elishasmiller', 806479, 4.0),
#  ('samy', 165525, 5.0),
#  ('michelleleecronk', 391519, 3.0),
#  ('Amy', 407134, 5.0),
#  ('ashleydoukas', 397005, 4.0),
#  ('Scorpio51', 708284, 5.0),
#  ('RockHero', 254770, 3.0),
#  ('Joanna', 715662, 4.0),
#  ('Melissa', 429442, 3.0),
#  ('Jamie', 136482, 5.0),
#  ('jcoffman121', 200824, 5.0),
#  ('rebeccalewthwaite', 668696, 5.0),
#  ('alysonwonderlandis', 668696, 4.0),
#  ('missashley7206', 520945, 5.0),
#  ('rebeccafear', 407134, 3.0),
#  ('Emily', 494869, 5.0),
#  ('Meh', 539980, 3.0),
#  ('Claire', 151160, 4.0),
#  ('Jen', 210299, 5.0),
#  ('Keriann', 656645, 1.0),
#  ('redleona1', 778295, 4.0),
#  ('kdearthlover928', 787518, 4.0),
#  ('cconowitch', 410263, 5.0),
#  ...]

# %%
dataset = data.build_full_trainset()
print('Number of users: ',dataset.n_users,'\n')
print('Number of items: ',dataset.n_items)
#Finding out that there are 1,376 items, probably better to use item-item similarity for neighborhood-based methods
# Out:
# Number of users:  32399
#
# Number of items:  1376

# %%
32399*1376
# Out:
# 44581024

# %%
82722/44581024 #Sparsity of our dataset
# Out:
# 0.001855542842622906

# %%
# importing relevant libraries for modeling 
from surprise.prediction_algorithms import knns
from surprise.similarities import cosine, msd, pearson
from surprise.model_selection import cross_validate
from surprise.prediction_algorithms import SVD
from surprise.prediction_algorithms import KNNWithMeans, KNNBasic, KNNBaseline
from surprise.model_selection import GridSearchCV

# %%
#Setting up two Metrics
sim_cos = {'name':'cosine','user_based':False}
sim_pearson = {'name':'pearson','user_based':False}

# %%
#Checking out Memory-Based Method (Neighborhood-Based)
# KNNBasic (using Cosine similarity as a metric)
basic = knns.KNNBasic(sim_options=sim_cos)
basic.fit(trainset)
predictions = basic.test(testset)
print(accuracy.rmse(predictions))
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.0351
# 1.0351479171269033

# %%
#KNNBasic (using Pearson similarity as a metric)
basic_pearson = knns.KNNBasic(sim_options=sim_pearson)
basic_pearson.fit(trainset)
predictions = basic_pearson.test(testset)
print(accuracy.rmse(predictions))
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.0530
# 1.0529607098068483

# %%
#KNNwithMeans (using Cosine similarity since it outperformed Pearson)
knn_means = knns.KNNWithMeans(sim_options=sim_cos)
knn_means.fit(trainset)
predictions = knn_means.test(testset)
print(accuracy.rmse(predictions))
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.0017
# 1.0016579061851512

# %%
#KNNBaseline (Cosine again, KNNBaseline includes bias term)
knn_baseline = knns.KNNBaseline(sim_options=sim_cos)
knn_baseline.fit(trainset)
predictions = knn_baseline.test(testset)
print(accuracy.rmse(predictions))
#Best Memory-Based Model run
# Out:
# Estimating biases using als...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9906
# 0.9905602538575518

# %%
#GridSearch on SVD to try out different parameters to find optimal ones
param_grid = {'n_factors':[20,50],'n_epochs': [5, 10], 'lr_all': [0.002, 0.005], 'reg_all': [0.4, 0.6]}
gs_model = GridSearchCV(SVD,param_grid=param_grid,n_jobs = -1,joblib_verbose=5)
gs_model.fit(data)
gs_model.best_params
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-122-2dc7c51c032d> in <module>
#       2 param_grid = {'n_factors':[20,50],'n_epochs': [5, 10], 'lr_all': [0.002, 0.005], 'reg_all': [0.4, 0.6]}
#       3 gs_model = GridSearchCV(SVD,param_grid=param_grid,n_jobs = -1,joblib_verbose=5)
# ----> 4 gs_model.fit(data)
#       5 gs_model.best_params
#
# ~/anaconda3/lib/python3.7/site-packages/surprise/model_selection/search.py in fit(self, data)
#      88         out = Parallel(n_jobs=self.n_jobs,
#      89                        pre_dispatch=self.pre_dispatch,
# ---> 90                        verbose=self.joblib_verbose)(delayed_list)
#      91
#      92         (test_measures_dicts,
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#     932
#     933             with self._backend.retrieval_context():
# --> 934                 self.retrieve()
#     935             # Make sure that we get a last message telling us we are done
#     936             elapsed_time = time.time() - self._start_time
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in retrieve(self)
#     831             try:
#     832                 if getattr(self._backend, 'supports_timeout', False):
# --> 833                     self._output.extend(job.get(timeout=self.timeout))
#     834                 else:
#     835                     self._output.extend(job.get())
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     519         AsyncResults.get from multiprocessing."""
#     520         try:
# --> 521             return future.result(timeout=timeout)
#     522         except LokyTimeoutError:
#     523             raise TimeoutError()
#
# ~/anaconda3/lib/python3.7/concurrent/futures/_base.py in result(self, timeout)
#     425                 return self.__get_result()
#     426
# --> 427             self._condition.wait(timeout)
#     428
#     429             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
gs_model.best_score
# Out:
# {'rmse': 0.9516386898822737, 'mae': 0.7705738445980524}

# %%
#GridSearch on SVD with different n_factors and reg_all
param_grid = {'n_factors':[20,30],'n_epochs': [5, 10], 'lr_all': [0.002, 0.005], 'reg_all': [0.2, 0.6]}
gs_modelA = GridSearchCV(SVD,param_grid=param_grid,n_jobs = -1,joblib_verbose=5)
gs_modelA.fit(data)
gs_modelA.best_params
#Looks like 10 n_factors with
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:   57.5s
# [Parallel(n_jobs=-1)]: Done  74 out of  80 | elapsed:  1.5min remaining:    7.2s
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed:  1.6min finished
# {'rmse': {'n_factors': 20, 'n_epochs': 10, 'lr_all': 0.005, 'reg_all': 0.2},
#  'mae': {'n_factors': 20, 'n_epochs': 10, 'lr_all': 0.005, 'reg_all': 0.6}}

# %%
gs_modelA.best_score
# Out:
# {'rmse': 0.9496501207952793, 'mae': 0.7704374909534012}

# %%
#GridSearch on SVD with different n_factors and reg_all
param_grid = {'n_factors':[10,20],'n_epochs': [5, 10], 'lr_all': [0.002, 0.005], 'reg_all': [0.2,0.4]}
gs_modelB = GridSearchCV(SVD,param_grid=param_grid,n_jobs = -1,joblib_verbose=5)
gs_modelB.fit(data)
gs_modelB.best_params
#Seems reg_all 0.2 is best while n_factors favoring lower values such as 5; does seem to have worse RMSE than previous
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:   56.8s
# [Parallel(n_jobs=-1)]: Done  74 out of  80 | elapsed:  1.5min remaining:    7.1s
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed:  1.6min finished
# {'rmse': {'n_factors': 10, 'n_epochs': 10, 'lr_all': 0.005, 'reg_all': 0.2},
#  'mae': {'n_factors': 10, 'n_epochs': 10, 'lr_all': 0.005, 'reg_all': 0.4}}

# %%
gs_modelB.best_score
# Out:
# {'rmse': 0.949614362152744, 'mae': 0.7707649004789687}

# %%
#SVD Model-Based Collaborative Filtering approach, with First GridSearch Optimal parameters 
svd = SVD(n_factors=20,n_epochs=10,lr_all=0.005,reg_all=0.4)
svd.fit(trainset)
predictions = svd.test(testset)
print(accuracy.rmse(predictions))
# Out:
# RMSE: 0.9598
# 0.9597748287818351

# %%
#SVD 3rd GridSearch Opt parameters
#decreasing n_factors to 10 and keeping reg_all at 0.2
svd = SVD(n_factors=10,n_epochs=10,lr_all=0.005,reg_all=0.2)
svd.fit(trainset)
predictions = svd.test(testset)
print(accuracy.rmse(predictions))
# Out:
# RMSE: 0.9582
# 0.9581739172584685

# %%
#SVD 2nd GridSearch Opt parameters
#just decreasing reg_all to 0.2
svd = SVD(n_factors=20,n_epochs=10,lr_all=0.005,reg_all=0.2)
svd.fit(trainset)
predictions = svd.test(testset)
print(accuracy.rmse(predictions))
#WINS with best parameters for our SVD model's performance
# Out:
# RMSE: 0.9581
# 0.9581301684253712

# %%
predictions
# Out:
# [Prediction(uid='furnclaws', iid=766618, r_ui=5.0, est=4.140721062232487, details={'was_impossible': False}),
#  Prediction(uid='mippy98', iid=486643, r_ui=5.0, est=3.685952797324401, details={'was_impossible': False}),
#  Prediction(uid='kayladesirae', iid=161592, r_ui=5.0, est=4.000364923417458, details={'was_impossible': False}),
#  Prediction(uid='bizzerickson', iid=380801, r_ui=3.0, est=4.033371396385716, details={'was_impossible': False}),
#  Prediction(uid='jnelson2386', iid=406357, r_ui=4.0, est=4.029533622249052, details={'was_impossible': False}),
#  Prediction(uid='Laura', iid=298256, r_ui=5.0, est=3.951181961046857, details={'was_impossible': False}),
#  Prediction(uid='Roxy', iid=659701, r_ui=5.0, est=4.496986323554833, details={'was_impossible': False}),
#  Prediction(uid='Amber', iid=787518, r_ui=5.0, est=4.1359006541742165, details={'was_impossible': False}),
#  Prediction(uid='clairecat98', iid=668800, r_ui=3.0, est=4.013094956713942, details={'was_impossible': False}),
#  Prediction(uid='Becky', iid=550103, r_ui=2.0, est=3.9263522003188727, details={'was_impossible': False}),
#  Prediction(uid='melissa_mercieca', iid=152702, r_ui=5.0, est=3.908368639753395, details={'was_impossible': False}),
#  Prediction(uid='Betsy', iid=538258, r_ui=4.0, est=3.9353547201122985, details={'was_impossible': False}),
#  Prediction(uid='hwheelan', iid=630114, r_ui=5.0, est=4.028255165184491, details={'was_impossible': False}),
#  Prediction(uid='libby.spotts', iid=653308, r_ui=5.0, est=4.08579974809957, details={'was_impossible': False}),
#  Prediction(uid='madison.b.murphy', iid=412737, r_ui=2.0, est=3.4522310649498267, details={'was_impossible': False}),
#  Prediction(uid='erinstutesman', iid=169727, r_ui=2.0, est=3.445017920643322, details={'was_impossible': False}),
#  Prediction(uid='bmartin0876', iid=410934, r_ui=4.0, est=4.007715245621582, details={'was_impossible': False}),
#  Prediction(uid='sarahlin.52992', iid=515644, r_ui=3.0, est=3.674214983313192, details={'was_impossible': False}),
#  Prediction(uid='littlemissmoe33', iid=519836, r_ui=3.0, est=3.6727830288392322, details={'was_impossible': False}),
#  Prediction(uid='chrystal.carey89', iid=539980, r_ui=5.0, est=3.9355772640367164, details={'was_impossible': False}),
#  Prediction(uid='ljgeiger7', iid=520945, r_ui=5.0, est=3.687211111356182, details={'was_impossible': False}),
#  Prediction(uid='Kristina', iid=502359, r_ui=3.0, est=3.695158736458647, details={'was_impossible': False}),
#  Prediction(uid='Heather', iid=806856, r_ui=3.0, est=4.3513859294508945, details={'was_impossible': False}),
#  Prediction(uid='Kathryn', iid=169727, r_ui=3.0, est=3.515501188771008, details={'was_impossible': False}),
#  Prediction(uid='beansandpenney', iid=407044, r_ui=5.0, est=3.7145125166628765, details={'was_impossible': False}),
#  Prediction(uid='kbachewicz', iid=482408, r_ui=5.0, est=4.281424691062077, details={'was_impossible': False}),
#  Prediction(uid='Yara', iid=698964, r_ui=2.0, est=3.8409507598214163, details={'was_impossible': False}),
#  Prediction(uid='hlarman', iid=396365, r_ui=4.0, est=4.187648513220064, details={'was_impossible': False}),
#  Prediction(uid='Elizabeth', iid=427567, r_ui=5.0, est=4.020194499281964, details={'was_impossible': False}),
#  Prediction(uid='Steph', iid=169727, r_ui=2.0, est=3.8070976259246962, details={'was_impossible': False}),
#  Prediction(uid='mswong88', iid=200824, r_ui=3.0, est=3.9745435195407453, details={'was_impossible': False}),
#  Prediction(uid='naiaveshadowmoon', iid=484879, r_ui=4.0, est=3.7390146024327775, details={'was_impossible': False}),
#  Prediction(uid='amydoefer', iid=338596, r_ui=5.0, est=4.105420876002002, details={'was_impossible': False}),
#  Prediction(uid='Diana', iid=693560, r_ui=2.0, est=3.535671328886032, details={'was_impossible': False}),
#  Prediction(uid='Kathrine', iid=454764, r_ui=4.0, est=4.463534552064597, details={'was_impossible': False}),
#  Prediction(uid='Christina', iid=427567, r_ui=5.0, est=4.1073115503410955, details={'was_impossible': False}),
#  Prediction(uid='Carmen', iid=698964, r_ui=3.0, est=4.076672134736121, details={'was_impossible': False}),
#  Prediction(uid='Zoe', iid=414247, r_ui=4.0, est=3.5117112563772013, details={'was_impossible': False}),
#  Prediction(uid='Melody', iid=152702, r_ui=5.0, est=4.075388428287919, details={'was_impossible': False}),
#  Prediction(uid='lauren', iid=391519, r_ui=5.0, est=3.9878171519980117, details={'was_impossible': False}),
#  Prediction(uid='andymhouse01', iid=520945, r_ui=5.0, est=3.6038480888815343, details={'was_impossible': False}),
#  Prediction(uid='emilyday1', iid=799325, r_ui=4.0, est=4.102864058651917, details={'was_impossible': False}),
#  Prediction(uid='k.c.farrell', iid=407044, r_ui=2.0, est=3.6760887282885886, details={'was_impossible': False}),
#  Prediction(uid='Tegan', iid=397005, r_ui=5.0, est=3.934576655568473, details={'was_impossible': False}),
#  Prediction(uid='wishup2thestars', iid=338596, r_ui=3.0, est=4.058378772920385, details={'was_impossible': False}),
#  Prediction(uid='ecsavageau', iid=454764, r_ui=4.0, est=4.06900484650313, details={'was_impossible': False}),
#  Prediction(uid='giuliamccauley', iid=136482, r_ui=4.0, est=3.9426424717071966, details={'was_impossible': False}),
#  Prediction(uid='Sarah', iid=697835, r_ui=5.0, est=4.105123870644745, details={'was_impossible': False}),
#  Prediction(uid='andreaguzman.1986', iid=604607, r_ui=5.0, est=4.087277303661414, details={'was_impossible': False}),
#  Prediction(uid='Angie', iid=407134, r_ui=3.0, est=3.733839372135561, details={'was_impossible': False}),
#  Prediction(uid='Ashleigh', iid=407574, r_ui=5.0, est=3.6007871586043154, details={'was_impossible': False}),
#  Prediction(uid='mayumi', iid=806479, r_ui=5.0, est=4.275369665719188, details={'was_impossible': False}),
#  Prediction(uid='jujubee747', iid=757731, r_ui=4.0, est=4.072061354403562, details={'was_impossible': False}),
#  Prediction(uid='Sarah', iid=397642, r_ui=5.0, est=3.883731432859203, details={'was_impossible': False}),
#  Prediction(uid='imabcool2day', iid=699784, r_ui=3.0, est=4.003355380457171, details={'was_impossible': False}),
#  Prediction(uid='robin.a.birt', iid=414857, r_ui=5.0, est=4.125684674927964, details={'was_impossible': False}),
#  Prediction(uid='KristinMarie', iid=753935, r_ui=3.0, est=3.841187133783681, details={'was_impossible': False}),
#  Prediction(uid='kaitiekov', iid=379278, r_ui=3.0, est=4.04509895719216, details={'was_impossible': False}),
#  Prediction(uid='sylvialauren81', iid=756722, r_ui=5.0, est=4.029396575014663, details={'was_impossible': False}),
#  Prediction(uid='Allison', iid=715662, r_ui=4.0, est=4.023826775012666, details={'was_impossible': False}),
#  Prediction(uid='missmodjeski', iid=765620, r_ui=5.0, est=3.548478380337882, details={'was_impossible': False}),
#  Prediction(uid='hannahlmarko', iid=539980, r_ui=3.0, est=3.9095956210870586, details={'was_impossible': False}),
#  Prediction(uid='smithcn', iid=161592, r_ui=5.0, est=4.074786662681303, details={'was_impossible': False}),
#  Prediction(uid='Katherine', iid=756073, r_ui=5.0, est=3.8141970846712807, details={'was_impossible': False}),
#  Prediction(uid='Moda', iid=427567, r_ui=5.0, est=4.258140216946501, details={'was_impossible': False}),
#  Prediction(uid='jessica.poeschl', iid=155572, r_ui=4.0, est=4.28958930398245, details={'was_impossible': False}),
#  Prediction(uid='andrea.j.szymanski', iid=806856, r_ui=5.0, est=4.408465935531985, details={'was_impossible': False}),
#  Prediction(uid='rebeccaameyers', iid=753935, r_ui=3.0, est=3.5229782225569197, details={'was_impossible': False}),
#  Prediction(uid='Naomi', iid=171740, r_ui=5.0, est=4.26927957777703, details={'was_impossible': False}),
#  Prediction(uid='jackie', iid=161514, r_ui=3.0, est=4.06193196418174, details={'was_impossible': False}),
#  Prediction(uid='Valerie', iid=715662, r_ui=5.0, est=4.019053467023107, details={'was_impossible': False}),
#  Prediction(uid='Nathalie', iid=391519, r_ui=4.0, est=4.185221616928765, details={'was_impossible': False}),
#  Prediction(uid='Christie', iid=392812, r_ui=5.0, est=3.602370553522621, details={'was_impossible': False}),
#  Prediction(uid='Lindsay', iid=402677, r_ui=3.0, est=3.621976273662428, details={'was_impossible': False}),
#  Prediction(uid='dominiquemathers', iid=125442, r_ui=3.0, est=4.18007314278362, details={'was_impossible': False}),
#  Prediction(uid='dcerezo93', iid=392144, r_ui=3.0, est=4.16316305930402, details={'was_impossible': False}),
#  Prediction(uid='SJ1984', iid=246671, r_ui=5.0, est=4.09886419605192, details={'was_impossible': False}),
#  Prediction(uid='kristynsmith6655321', iid=136482, r_ui=5.0, est=3.993481112893467, details={'was_impossible': False}),
#  Prediction(uid='sweet_pea_712', iid=429442, r_ui=3.0, est=4.0292335722597175, details={'was_impossible': False}),
#  Prediction(uid='Emily', iid=658440, r_ui=3.0, est=4.076401343529746, details={'was_impossible': False}),
#  Prediction(uid='Gabrielle', iid=477210, r_ui=4.0, est=3.5611258403187733, details={'was_impossible': False}),
#  Prediction(uid='Nikki', iid=125442, r_ui=5.0, est=4.219559751242637, details={'was_impossible': False}),
#  Prediction(uid='Christine', iid=654585, r_ui=5.0, est=3.82834675884067, details={'was_impossible': False}),
#  Prediction(uid='caity.hohmann', iid=754891, r_ui=5.0, est=3.756740359482148, details={'was_impossible': False}),
#  Prediction(uid='Amber', iid=781127, r_ui=4.0, est=4.130861228411084, details={'was_impossible': False}),
#  Prediction(uid='cfreeman', iid=454030, r_ui=4.0, est=4.02043772847329, details={'was_impossible': False}),
#  Prediction(uid='smbschroeder', iid=520945, r_ui=4.0, est=3.6038480888815343, details={'was_impossible': False}),
#  Prediction(uid='Silence', iid=539980, r_ui=4.0, est=3.8726074671635335, details={'was_impossible': False}),
#  Prediction(uid='kirs10hurst', iid=429442, r_ui=3.0, est=4.168438794699969, details={'was_impossible': False}),
#  Prediction(uid='alliecatwoman', iid=604607, r_ui=4.0, est=4.029962795338918, details={'was_impossible': False}),
#  Prediction(uid='kellyanneburns', iid=414857, r_ui=5.0, est=4.082992371034622, details={'was_impossible': False}),
#  Prediction(uid='schmidtkg', iid=604607, r_ui=4.0, est=4.025124122980641, details={'was_impossible': False}),
#  Prediction(uid='teana.campbell', iid=144486, r_ui=5.0, est=4.075908873153329, details={'was_impossible': False}),
#  Prediction(uid='rotashark', iid=158723, r_ui=4.0, est=4.039385853839019, details={'was_impossible': False}),
#  Prediction(uid='mkronfeld', iid=539980, r_ui=3.0, est=3.9517856869571593, details={'was_impossible': False}),
#  Prediction(uid='Miranda', iid=657242, r_ui=5.0, est=3.9611337146916594, details={'was_impossible': False}),
#  Prediction(uid='trent1at', iid=785517, r_ui=5.0, est=4.033342972744084, details={'was_impossible': False}),
#  Prediction(uid='Sandy', iid=715501, r_ui=4.0, est=3.4376530557448413, details={'was_impossible': False}),
#  Prediction(uid='charlene.vela', iid=633619, r_ui=5.0, est=4.0187696188835345, details={'was_impossible': False}),
#  Prediction(uid='mgjgoodridge', iid=163758, r_ui=5.0, est=3.8503581747228965, details={'was_impossible': False}),
#  Prediction(uid='judysbelle', iid=645822, r_ui=5.0, est=3.977789590228332, details={'was_impossible': False}),
#  Prediction(uid='vindycator77', iid=407044, r_ui=4.0, est=3.6760887282885886, details={'was_impossible': False}),
#  Prediction(uid='Michelle', iid=404557, r_ui=3.0, est=3.6759468342314663, details={'was_impossible': False}),
#  Prediction(uid='megshalley', iid=538258, r_ui=2.0, est=3.752555845071032, details={'was_impossible': False}),
#  Prediction(uid='abbeyclark', iid=440351, r_ui=5.0, est=3.9535942578950465, details={'was_impossible': False}),
#  Prediction(uid='randi.pgaint', iid=139123, r_ui=4.0, est=4.155520741817113, details={'was_impossible': False}),
#  Prediction(uid='AUDRA', iid=161514, r_ui=5.0, est=3.977927550402762, details={'was_impossible': False}),
#  Prediction(uid='ctinahernandz', iid=125442, r_ui=4.0, est=4.191908680175277, details={'was_impossible': False}),
#  Prediction(uid='lisa.petrakis', iid=427567, r_ui=4.0, est=3.9640874418462952, details={'was_impossible': False}),
#  Prediction(uid='theatricalkyla', iid=756073, r_ui=3.0, est=3.99375701986216, details={'was_impossible': False}),
#  Prediction(uid='Celeste', iid=707014, r_ui=5.0, est=3.9504626978200976, details={'was_impossible': False}),
#  Prediction(uid='cdehlinger7923', iid=708795, r_ui=4.0, est=3.9594272827659935, details={'was_impossible': False}),
#  Prediction(uid='kermit1999', iid=404557, r_ui=2.0, est=3.423130410856092, details={'was_impossible': False}),
#  Prediction(uid='mk.shields4', iid=269063, r_ui=3.0, est=4.267741493804239, details={'was_impossible': False}),
#  Prediction(uid='trc5017', iid=481011, r_ui=3.0, est=3.5511747015868877, details={'was_impossible': False}),
#  Prediction(uid='julie.a.johnson', iid=684260, r_ui=3.0, est=3.3940071661049562, details={'was_impossible': False}),
#  Prediction(uid='amynberlin', iid=647551, r_ui=5.0, est=4.167246965930825, details={'was_impossible': False}),
#  Prediction(uid='ladyhope78', iid=407134, r_ui=4.0, est=3.6666484195543663, details={'was_impossible': False}),
#  Prediction(uid='Amy', iid=165525, r_ui=2.0, est=3.5260632649357424, details={'was_impossible': False}),
#  Prediction(uid='sanchez_maria12', iid=806856, r_ui=3.0, est=4.044598902666916, details={'was_impossible': False}),
#  Prediction(uid='Maritza', iid=189315, r_ui=5.0, est=4.175354691116314, details={'was_impossible': False}),
#  Prediction(uid='ana', iid=484879, r_ui=4.0, est=3.7821603059860265, details={'was_impossible': False}),
#  Prediction(uid='aprilskanklin', iid=657081, r_ui=5.0, est=3.7215562530154647, details={'was_impossible': False}),
#  Prediction(uid='Kat', iid=427567, r_ui=3.0, est=4.060727875403485, details={'was_impossible': False}),
#  Prediction(uid='jennellmaddox', iid=397005, r_ui=5.0, est=4.026183098495816, details={'was_impossible': False}),
#  Prediction(uid='taraflorio', iid=414857, r_ui=4.0, est=4.102960190103813, details={'was_impossible': False}),
#  Prediction(uid='rozbtaylor', iid=530472, r_ui=4.0, est=3.94160643622783, details={'was_impossible': False}),
#  Prediction(uid='lindsy', iid=539980, r_ui=5.0, est=4.049832694742238, details={'was_impossible': False}),
#  Prediction(uid='Michele', iid=656645, r_ui=4.0, est=3.8331341114281967, details={'was_impossible': False}),
#  Prediction(uid='Tracy', iid=419547, r_ui=5.0, est=4.028529148702625, details={'was_impossible': False}),
#  Prediction(uid='Joyce W', iid=136482, r_ui=3.0, est=3.895196994857325, details={'was_impossible': False}),
#  Prediction(uid='monika.the.awesome', iid=427567, r_ui=5.0, est=4.014530284263556, details={'was_impossible': False}),
#  Prediction(uid='Brittany', iid=668696, r_ui=5.0, est=4.258286703082334, details={'was_impossible': False}),
#  Prediction(uid='Adaire', iid=126885, r_ui=5.0, est=3.835696948022991, details={'was_impossible': False}),
#  Prediction(uid='Natasha', iid=147714, r_ui=3.0, est=4.078586096819996, details={'was_impossible': False}),
#  Prediction(uid='Ashley', iid=445254, r_ui=5.0, est=4.3742957498427035, details={'was_impossible': False}),
#  Prediction(uid='lachilydomi', iid=400541, r_ui=4.0, est=4.342409051626553, details={'was_impossible': False}),
#  Prediction(uid='nicolevaughnmusic', iid=659701, r_ui=5.0, est=4.3439057075757, details={'was_impossible': False}),
#  Prediction(uid='beth_martin3', iid=397005, r_ui=5.0, est=4.022524651188211, details={'was_impossible': False}),
#  Prediction(uid='lorwyn45', iid=210299, r_ui=4.0, est=3.866205344730504, details={'was_impossible': False}),
#  Prediction(uid='hmueller88', iid=454030, r_ui=3.0, est=4.1135118203738035, details={'was_impossible': False}),
#  Prediction(uid='barb.brogan', iid=412737, r_ui=5.0, est=3.6130366380218577, details={'was_impossible': False}),
#  Prediction(uid='electric.wings', iid=753429, r_ui=4.0, est=3.9352888032106423, details={'was_impossible': False}),
#  Prediction(uid='leitingerej', iid=416942, r_ui=4.0, est=3.89445623347307, details={'was_impossible': False}),
#  Prediction(uid='kolbe.victoria', iid=401503, r_ui=5.0, est=3.6136585468508446, details={'was_impossible': False}),
#  Prediction(uid='corablouch', iid=639328, r_ui=4.0, est=4.070794941356551, details={'was_impossible': False}),
#  Prediction(uid='Jamie', iid=630114, r_ui=5.0, est=4.025615040570566, details={'was_impossible': False}),
#  Prediction(uid='Amy', iid=175771, r_ui=4.0, est=4.050243342779067, details={'was_impossible': False}),
#  Prediction(uid='Emon', iid=144486, r_ui=5.0, est=4.062277986267972, details={'was_impossible': False}),
#  Prediction(uid='kaydyan', iid=647551, r_ui=5.0, est=4.103863748968765, details={'was_impossible': False}),
#  Prediction(uid='emotastic', iid=796383, r_ui=4.0, est=3.8086193045314496, details={'was_impossible': False}),
#  Prediction(uid='Evey', iid=462796, r_ui=3.0, est=4.072516516814956, details={'was_impossible': False}),
#  Prediction(uid='Tori', iid=416738, r_ui=5.0, est=4.1399877045652005, details={'was_impossible': False}),
#  Prediction(uid='Chibird', iid=380801, r_ui=4.0, est=3.993254155068343, details={'was_impossible': False}),
#  Prediction(uid='Siri', iid=353933, r_ui=4.0, est=4.1217595772405415, details={'was_impossible': False}),
#  Prediction(uid='cherry_kitty1', iid=633619, r_ui=3.0, est=4.164072799861662, details={'was_impossible': False}),
#  Prediction(uid='gina', iid=136482, r_ui=5.0, est=4.113428760291371, details={'was_impossible': False}),
#  Prediction(uid='cutemouse07', iid=668696, r_ui=3.0, est=4.145036055124333, details={'was_impossible': False}),
#  Prediction(uid='Ashley', iid=668696, r_ui=4.0, est=4.1801384751683335, details={'was_impossible': False}),
#  Prediction(uid='katieb619', iid=175771, r_ui=5.0, est=4.04657167592742, details={'was_impossible': False}),
#  Prediction(uid='vickijenn', iid=200824, r_ui=4.0, est=3.940691996788477, details={'was_impossible': False}),
#  Prediction(uid='madeleine.currie', iid=169727, r_ui=3.0, est=3.5903421850441193, details={'was_impossible': False}),
#  Prediction(uid='Natalie', iid=390319, r_ui=3.0, est=4.354184531251712, details={'was_impossible': False}),
#  Prediction(uid='Andrea', iid=753935, r_ui=2.0, est=3.897070116382798, details={'was_impossible': False}),
#  Prediction(uid='hildesama', iid=578438, r_ui=3.0, est=3.649898744721787, details={'was_impossible': False}),
#  Prediction(uid='lannanstoner', iid=503595, r_ui=5.0, est=3.887493674804107, details={'was_impossible': False}),
#  Prediction(uid='Elisabeth', iid=407044, r_ui=3.0, est=3.5341902908933904, details={'was_impossible': False}),
#  Prediction(uid='Caro', iid=152702, r_ui=4.0, est=3.889685164664366, details={'was_impossible': False}),
#  Prediction(uid='hoy_becky', iid=175771, r_ui=3.0, est=3.9490832307381174, details={'was_impossible': False}),
#  Prediction(uid='Meg', iid=792842, r_ui=5.0, est=3.893334781834886, details={'was_impossible': False}),
#  Prediction(uid='Audrey', iid=698449, r_ui=4.0, est=4.289216563988259, details={'was_impossible': False}),
#  Prediction(uid='jlrivera17', iid=414857, r_ui=5.0, est=4.35176410138998, details={'was_impossible': False}),
#  Prediction(uid='joswiak.kendra', iid=200824, r_ui=5.0, est=3.9745435195407453, details={'was_impossible': False}),
#  Prediction(uid='Emily', iid=780724, r_ui=5.0, est=3.766602815988932, details={'was_impossible': False}),
#  Prediction(uid='denise', iid=367240, r_ui=4.0, est=4.181946222011448, details={'was_impossible': False}),
#  Prediction(uid='ctb.photography', iid=792842, r_ui=4.0, est=3.8149905604883894, details={'was_impossible': False}),
#  Prediction(uid='myripped_jeans', iid=645822, r_ui=3.0, est=3.9158512802083294, details={'was_impossible': False}),
#  Prediction(uid='ambergochoel', iid=391519, r_ui=5.0, est=4.127195221222206, details={'was_impossible': False}),
#  Prediction(uid='kwiggins.rowan', iid=806856, r_ui=2.0, est=4.240514865650589, details={'was_impossible': False}),
#  Prediction(uid='g.golando', iid=175771, r_ui=5.0, est=3.9986113524869005, details={'was_impossible': False}),
#  Prediction(uid='emchard83', iid=391519, r_ui=3.0, est=4.083317981903166, details={'was_impossible': False}),
#  Prediction(uid='max0787', iid=693560, r_ui=5.0, est=3.6346586335014934, details={'was_impossible': False}),
#  Prediction(uid='me', iid=200824, r_ui=3.0, est=3.567885785876097, details={'was_impossible': False}),
#  Prediction(uid='ashleighp13', iid=652823, r_ui=3.0, est=3.608824312829976, details={'was_impossible': False}),
#  Prediction(uid='ashdenooij', iid=423572, r_ui=5.0, est=4.255104008883799, details={'was_impossible': False}),
#  Prediction(uid='Heather', iid=397005, r_ui=5.0, est=4.033363912403995, details={'was_impossible': False}),
#  Prediction(uid='izzybeth', iid=697835, r_ui=3.0, est=4.094159239137722, details={'was_impossible': False}),
#  Prediction(uid='Sarah M.', iid=153494, r_ui=3.0, est=3.7428707495425817, details={'was_impossible': False}),
#  Prediction(uid='csieferman', iid=633619, r_ui=5.0, est=4.041262074838712, details={'was_impossible': False}),
#  Prediction(uid='cfrazetta', iid=657242, r_ui=2.0, est=3.514354604592067, details={'was_impossible': False}),
#  Prediction(uid='emilycrochetiere', iid=391519, r_ui=5.0, est=4.083317981903166, details={'was_impossible': False}),
#  Prediction(uid='jenn.marie.hertel', iid=412737, r_ui=4.0, est=3.6966987979693964, details={'was_impossible': False}),
#  Prediction(uid='Tahnee', iid=416738, r_ui=5.0, est=4.125741912550877, details={'was_impossible': False}),
#  Prediction(uid='Phoebe of Fuzzy Pickles', iid=175771, r_ui=4.0, est=4.128815240808677, details={'was_impossible': False}),
#  Prediction(uid='alaterza13', iid=538258, r_ui=2.0, est=3.8649024637196723, details={'was_impossible': False}),
#  Prediction(uid='sidneystilwell', iid=515644, r_ui=2.0, est=3.8620031703058593, details={'was_impossible': False}),
#  Prediction(uid='greenturtle03', iid=454030, r_ui=1.0, est=4.140910870158372, details={'was_impossible': False}),
#  Prediction(uid='Julie', iid=502359, r_ui=4.0, est=3.9850705811081477, details={'was_impossible': False}),
#  Prediction(uid='Jennifer', iid=723208, r_ui=5.0, est=4.006217796415911, details={'was_impossible': False}),
#  Prediction(uid='rachelwagoner84', iid=539980, r_ui=3.0, est=3.9078655972348764, details={'was_impossible': False}),
#  Prediction(uid='brody.jill', iid=515644, r_ui=4.0, est=3.6672527124244176, details={'was_impossible': False}),
#  Prediction(uid='Mod_Franny', iid=712030, r_ui=4.0, est=3.7664860257833612, details={'was_impossible': False}),
#  Prediction(uid='Nicole', iid=502359, r_ui=3.0, est=3.8464177188715434, details={'was_impossible': False}),
#  Prediction(uid='generalpershing473', iid=655211, r_ui=3.0, est=3.857087279999764, details={'was_impossible': False}),
#  Prediction(uid='sandrafarkas1', iid=414857, r_ui=4.0, est=4.082992371034622, details={'was_impossible': False}),
#  Prediction(uid='Maeve', iid=360958, r_ui=5.0, est=3.8671140751216906, details={'was_impossible': False}),
#  Prediction(uid='Elizabeth', iid=200824, r_ui=3.0, est=4.033213063934831, details={'was_impossible': False}),
#  Prediction(uid='ldxodancer', iid=397642, r_ui=4.0, est=3.88027301444066, details={'was_impossible': False}),
#  Prediction(uid='Jasmyn', iid=668696, r_ui=4.0, est=4.145036055124333, details={'was_impossible': False}),
#  Prediction(uid='leira237', iid=445254, r_ui=3.0, est=4.30269695177326, details={'was_impossible': False}),
#  Prediction(uid='kadiesteward', iid=806479, r_ui=3.0, est=4.228898158579292, details={'was_impossible': False}),
#  Prediction(uid='amber.manfredi', iid=539980, r_ui=4.0, est=4.00167636095441, details={'was_impossible': False}),
#  Prediction(uid='bluehalo1981', iid=404557, r_ui=3.0, est=3.688820732432641, details={'was_impossible': False}),
#  Prediction(uid='Stephanie', iid=645822, r_ui=5.0, est=4.083004665107739, details={'was_impossible': False}),
#  Prediction(uid='cktheisen07', iid=503595, r_ui=3.0, est=3.821407979049019, details={'was_impossible': False}),
#  Prediction(uid='Sabrina', iid=412737, r_ui=3.0, est=3.2930849253752936, details={'was_impossible': False}),
#  Prediction(uid='emmajamorama', iid=397005, r_ui=5.0, est=4.060392241014085, details={'was_impossible': False}),
#  Prediction(uid='lipsxhipsxenvy', iid=777527, r_ui=3.0, est=4.131351561757739, details={'was_impossible': False}),
#  Prediction(uid='jessicathehearn', iid=757731, r_ui=5.0, est=3.9745546969284145, details={'was_impossible': False}),
#  Prediction(uid='daniklic', iid=130225, r_ui=3.0, est=3.266952667099971, details={'was_impossible': False}),
#  Prediction(uid='joonuper', iid=539980, r_ui=3.0, est=3.9544551634552474, details={'was_impossible': False}),
#  Prediction(uid='Bikelover', iid=225354, r_ui=5.0, est=3.7356940713975693, details={'was_impossible': False}),
#  Prediction(uid='courtney.fischbach', iid=416738, r_ui=4.0, est=4.0065017586254, details={'was_impossible': False}),
#  Prediction(uid='prettynprple', iid=715662, r_ui=5.0, est=4.011368097455163, details={'was_impossible': False}),
#  Prediction(uid='raerae753', iid=456078, r_ui=5.0, est=3.9208888190271165, details={'was_impossible': False}),
#  Prediction(uid='Kelsie', iid=454764, r_ui=4.0, est=4.034466126854134, details={'was_impossible': False}),
#  Prediction(uid='goondy211', iid=125442, r_ui=5.0, est=4.2487647989730615, details={'was_impossible': False}),
#  Prediction(uid='Geraldine', iid=647235, r_ui=4.0, est=4.22140439620756, details={'was_impossible': False}),
#  Prediction(uid='viqtbrad', iid=147714, r_ui=3.0, est=4.078190794183704, details={'was_impossible': False}),
#  Prediction(uid='qxyhrox', iid=697835, r_ui=4.0, est=4.141685102559152, details={'was_impossible': False}),
#  Prediction(uid='b', iid=668696, r_ui=4.0, est=4.207396810364367, details={'was_impossible': False}),
#  Prediction(uid='ahulet', iid=410934, r_ui=5.0, est=4.018091983876859, details={'was_impossible': False}),
#  Prediction(uid='monikaelise', iid=722362, r_ui=1.0, est=3.8747425887267166, details={'was_impossible': False}),
#  Prediction(uid='Amanda', iid=175771, r_ui=4.0, est=3.9993224888669823, details={'was_impossible': False}),
#  Prediction(uid='crystalg46', iid=407134, r_ui=2.0, est=3.568187320249626, details={'was_impossible': False}),
#  Prediction(uid='hborst', iid=397005, r_ui=4.0, est=4.0256881347227145, details={'was_impossible': False}),
#  Prediction(uid='amandababanda', iid=484879, r_ui=2.0, est=3.7388888345473705, details={'was_impossible': False}),
#  Prediction(uid='penelope.nerd475', iid=756073, r_ui=4.0, est=3.99375701986216, details={'was_impossible': False}),
#  Prediction(uid='jljones1987', iid=645822, r_ui=4.0, est=3.977789590228332, details={'was_impossible': False}),
#  Prediction(uid='ashlie.elizabeth.moore', iid=155572, r_ui=4.0, est=4.28958930398245, details={'was_impossible': False}),
#  Prediction(uid='Darla', iid=539980, r_ui=2.0, est=3.9253543146612344, details={'was_impossible': False}),
#  Prediction(uid='aabbott96', iid=796383, r_ui=3.0, est=3.770510794185876, details={'was_impossible': False}),
#  Prediction(uid='zombianca', iid=210299, r_ui=4.0, est=3.866205344730504, details={'was_impossible': False}),
#  Prediction(uid='whittingtonam89', iid=803768, r_ui=4.0, est=3.4997493732094433, details={'was_impossible': False}),
#  Prediction(uid='kristen.lea', iid=779640, r_ui=4.0, est=4.056379306611807, details={'was_impossible': False}),
#  Prediction(uid='cgorss', iid=503595, r_ui=4.0, est=3.8417354238978216, details={'was_impossible': False}),
#  Prediction(uid='courtney.fenwick', iid=412003, r_ui=4.0, est=3.548072595691209, details={'was_impossible': False}),
#  Prediction(uid='laurel.needell', iid=781127, r_ui=4.0, est=4.132627086593505, details={'was_impossible': False}),
#  Prediction(uid='belleholder', iid=756722, r_ui=5.0, est=3.7142179546538983, details={'was_impossible': False}),
#  Prediction(uid='leprechaun426', iid=298256, r_ui=3.0, est=3.9037997349687004, details={'was_impossible': False}),
#  Prediction(uid='Paulina', iid=397005, r_ui=3.0, est=4.023432592418622, details={'was_impossible': False}),
#  Prediction(uid='shy_wardyn', iid=755526, r_ui=3.0, est=3.868674112476492, details={'was_impossible': False}),
#  Prediction(uid='Sarah', iid=715501, r_ui=4.0, est=3.5814652499738084, details={'was_impossible': False}),
#  Prediction(uid='joshelly12', iid=806856, r_ui=3.0, est=4.340118434130667, details={'was_impossible': False}),
#  Prediction(uid='crjuarez7', iid=165716, r_ui=5.0, est=3.841073566510554, details={'was_impossible': False}),
#  Prediction(uid='Jennifer', iid=787518, r_ui=5.0, est=4.204478250944162, details={'was_impossible': False}),
#  Prediction(uid='Angela', iid=147714, r_ui=4.0, est=4.199203762177468, details={'was_impossible': False}),
#  Prediction(uid='Bethany', iid=668696, r_ui=5.0, est=4.22172122149892, details={'was_impossible': False}),
#  Prediction(uid='amy.mantz', iid=412737, r_ui=3.0, est=3.5639359596936595, details={'was_impossible': False}),
#  Prediction(uid='kate', iid=539980, r_ui=5.0, est=3.921921848317185, details={'was_impossible': False}),
#  Prediction(uid='drea.stone', iid=756722, r_ui=3.0, est=3.872072448428579, details={'was_impossible': False}),
#  Prediction(uid='Monica', iid=152513, r_ui=4.0, est=4.256490319271581, details={'was_impossible': False}),
#  Prediction(uid='laurabowen6813', iid=412737, r_ui=4.0, est=3.6130366380218577, details={'was_impossible': False}),
#  Prediction(uid='annieviz', iid=338596, r_ui=4.0, est=4.0127454307047214, details={'was_impossible': False}),
#  Prediction(uid='Anne', iid=661169, r_ui=4.0, est=3.636375706788862, details={'was_impossible': False}),
#  Prediction(uid='erin.skovmand', iid=224493, r_ui=1.0, est=3.804256102896972, details={'was_impossible': False}),
#  Prediction(uid='kellie.grace7', iid=806856, r_ui=3.0, est=4.340118434130667, details={'was_impossible': False}),
#  Prediction(uid='ercw1998', iid=805642, r_ui=5.0, est=4.204511909190519, details={'was_impossible': False}),
#  Prediction(uid='whitney.tarver', iid=387118, r_ui=5.0, est=3.7901399080307954, details={'was_impossible': False}),
#  Prediction(uid='ladybugcardoza', iid=581432, r_ui=2.0, est=3.550055205141691, details={'was_impossible': False}),
#  Prediction(uid='Sarah', iid=146231, r_ui=5.0, est=3.5307513632349226, details={'was_impossible': False}),
#  Prediction(uid='amy.schiavo', iid=412003, r_ui=3.0, est=3.5009844345572017, details={'was_impossible': False}),
#  Prediction(uid='Lauree', iid=484879, r_ui=4.0, est=3.7390146024327775, details={'was_impossible': False}),
#  Prediction(uid='roobabe5566', iid=712030, r_ui=5.0, est=3.6939052833757713, details={'was_impossible': False}),
#  Prediction(uid='Kat', iid=391519, r_ui=4.0, est=4.184348604963336, details={'was_impossible': False}),
#  Prediction(uid='samantha.s.stockwell', iid=269063, r_ui=4.0, est=4.163201102732239, details={'was_impossible': False}),
#  Prediction(uid='chandlercathleen', iid=699784, r_ui=4.0, est=4.0285411485524945, details={'was_impossible': False}),
#  Prediction(uid='holly.harwood', iid=143287, r_ui=4.0, est=4.1692027828341915, details={'was_impossible': False}),
#  Prediction(uid='Aubrey', iid=400541, r_ui=5.0, est=4.23555547657087, details={'was_impossible': False}),
#  Prediction(uid='Corrie', iid=517055, r_ui=4.0, est=3.8338754156360486, details={'was_impossible': False}),
#  Prediction(uid='Kara', iid=335792, r_ui=5.0, est=4.31369603067244, details={'was_impossible': False}),
#  Prediction(uid='wintergreen14', iid=423572, r_ui=5.0, est=4.130402759651763, details={'was_impossible': False}),
#  Prediction(uid='pawwizard', iid=697835, r_ui=2.0, est=4.104235756852971, details={'was_impossible': False}),
#  Prediction(uid='Briana', iid=397224, r_ui=4.0, est=4.069459853234301, details={'was_impossible': False}),
#  Prediction(uid='urban.suburbia', iid=735892, r_ui=4.0, est=3.9491817398794145, details={'was_impossible': False}),
#  Prediction(uid='mlupher', iid=715662, r_ui=4.0, est=4.063632010898952, details={'was_impossible': False}),
#  Prediction(uid='pinkdolphin11', iid=661775, r_ui=2.0, est=3.601093706835827, details={'was_impossible': False}),
#  Prediction(uid='danamooney64', iid=469939, r_ui=3.0, est=3.74557461134138, details={'was_impossible': False}),
#  Prediction(uid='earlbie', iid=417269, r_ui=4.0, est=4.444016315400266, details={'was_impossible': False}),
#  Prediction(uid='Midori', iid=780724, r_ui=4.0, est=3.763777325996023, details={'was_impossible': False}),
#  Prediction(uid='kristinmsokul', iid=168387, r_ui=4.0, est=4.048379226387161, details={'was_impossible': False}),
#  Prediction(uid='joan.v.mclaughlin', iid=806479, r_ui=4.0, est=4.275369665719188, details={'was_impossible': False}),
#  Prediction(uid='dwmuts2s4s', iid=757731, r_ui=5.0, est=4.038782017194141, details={'was_impossible': False}),
#  Prediction(uid='allison', iid=629125, r_ui=3.0, est=4.060911228359672, details={'was_impossible': False}),
#  Prediction(uid='brittany', iid=165525, r_ui=3.0, est=3.655476378638387, details={'was_impossible': False}),
#  Prediction(uid='abaranowski410', iid=757242, r_ui=3.0, est=3.72256245920864, details={'was_impossible': False}),
#  Prediction(uid='alsbachh', iid=454030, r_ui=4.0, est=4.271775601950841, details={'was_impossible': False}),
#  Prediction(uid='Sara', iid=640171, r_ui=3.0, est=4.0390118577352645, details={'was_impossible': False}),
#  Prediction(uid='Meghan', iid=515644, r_ui=4.0, est=3.7489431408404768, details={'was_impossible': False}),
#  Prediction(uid='Amber', iid=147714, r_ui=4.0, est=4.070199347666726, details={'was_impossible': False}),
#  Prediction(uid='Britt', iid=668696, r_ui=5.0, est=4.194456777430167, details={'was_impossible': False}),
#  Prediction(uid='Anna', iid=338596, r_ui=4.0, est=4.2074715979042425, details={'was_impossible': False}),
#  Prediction(uid='Candace', iid=171740, r_ui=5.0, est=4.380500431830797, details={'was_impossible': False}),
#  Prediction(uid='Sara', iid=139838, r_ui=3.0, est=3.711643842954713, details={'was_impossible': False}),
#  Prediction(uid='tinabinapb', iid=655211, r_ui=3.0, est=3.9287442883143093, details={'was_impossible': False}),
#  Prediction(uid='Kaitlyn', iid=647235, r_ui=5.0, est=4.151861505559622, details={'was_impossible': False}),
#  Prediction(uid='Tara', iid=391519, r_ui=4.0, est=4.21866238427951, details={'was_impossible': False}),
#  Prediction(uid='Sara', iid=796383, r_ui=4.0, est=3.8708652346906183, details={'was_impossible': False}),
#  Prediction(uid='twrose2', iid=380801, r_ui=3.0, est=4.033371396385716, details={'was_impossible': False}),
#  Prediction(uid='mary.mccarthy91', iid=723977, r_ui=5.0, est=4.2443501279541636, details={'was_impossible': False}),
#  Prediction(uid='lucila.peretti', iid=715662, r_ui=5.0, est=4.020763518667164, details={'was_impossible': False}),
#  Prediction(uid='Leslie', iid=657081, r_ui=2.0, est=3.607733051925039, details={'was_impossible': False}),
#  Prediction(uid='Lauren', iid=757731, r_ui=5.0, est=4.054470795712923, details={'was_impossible': False}),
#  Prediction(uid='bmc257', iid=474002, r_ui=4.0, est=3.551226371797925, details={'was_impossible': False}),
#  Prediction(uid='taysialouise', iid=693560, r_ui=2.0, est=3.7148527401827915, details={'was_impossible': False}),
#  Prediction(uid='aubreyannalarson', iid=414857, r_ui=4.0, est=4.033820403639291, details={'was_impossible': False}),
#  Prediction(uid='Elvira', iid=210299, r_ui=1.0, est=3.911260972075664, details={'was_impossible': False}),
#  Prediction(uid='Amy Lee', iid=654585, r_ui=5.0, est=4.002399814690618, details={'was_impossible': False}),
#  Prediction(uid='emma.kantola', iid=695751, r_ui=4.0, est=4.052228656357021, details={'was_impossible': False}),
#  Prediction(uid='Justine', iid=670235, r_ui=5.0, est=3.951278272763245, details={'was_impossible': False}),
#  Prediction(uid='Nikki', iid=427567, r_ui=4.0, est=3.9914882146685446, details={'was_impossible': False}),
#  Prediction(uid='Katie', iid=130225, r_ui=3.0, est=3.2466330942915653, details={'was_impossible': False}),
#  Prediction(uid='scrapsasch', iid=803768, r_ui=4.0, est=3.5922997817740154, details={'was_impossible': False}),
#  Prediction(uid='jennbraund', iid=645822, r_ui=4.0, est=3.977789590228332, details={'was_impossible': False}),
#  Prediction(uid='Sarah', iid=171125, r_ui=4.0, est=3.8067829121188472, details={'was_impossible': False}),
#  Prediction(uid='M', iid=200824, r_ui=5.0, est=4.13399419536161, details={'was_impossible': False}),
#  Prediction(uid='Jessica', iid=539980, r_ui=5.0, est=3.9673331580897333, details={'was_impossible': False}),
#  Prediction(uid='nicole.padinha', iid=519836, r_ui=5.0, est=3.887576651701249, details={'was_impossible': False}),
#  Prediction(uid='spdrdrvre', iid=125442, r_ui=4.0, est=4.269158765672143, details={'was_impossible': False}),
#  Prediction(uid='Sydney', iid=616360, r_ui=5.0, est=4.126640298173376, details={'was_impossible': False}),
#  Prediction(uid='amanda.t.parrish', iid=630114, r_ui=3.0, est=4.028255165184491, details={'was_impossible': False}),
#  Prediction(uid='sarajeglum', iid=124761, r_ui=3.0, est=3.6778359525014284, details={'was_impossible': False}),
#  Prediction(uid='shaunalreynolds', iid=661775, r_ui=2.0, est=3.4916066649152864, details={'was_impossible': False}),
#  Prediction(uid='mlower.esq', iid=161514, r_ui=4.0, est=4.015086676011795, details={'was_impossible': False}),
#  Prediction(uid='epeery09', iid=647235, r_ui=5.0, est=4.112705084412012, details={'was_impossible': False}),
#  Prediction(uid='zzlai112199', iid=175771, r_ui=2.0, est=3.9986113524869005, details={'was_impossible': False}),
#  Prediction(uid='rachelmelissabrown', iid=539980, r_ui=3.0, est=4.05935427857467, details={'was_impossible': False}),
#  Prediction(uid='sugie0202', iid=768741, r_ui=5.0, est=3.9392403110082785, details={'was_impossible': False}),
#  Prediction(uid='crunkkidcatholic', iid=539980, r_ui=5.0, est=4.00167636095441, details={'was_impossible': False}),
#  Prediction(uid='Cori', iid=416738, r_ui=5.0, est=4.085969065685302, details={'was_impossible': False}),
#  Prediction(uid='ashley', iid=170806, r_ui=3.0, est=4.197732605458439, details={'was_impossible': False}),
#  Prediction(uid='JaninaVH', iid=143287, r_ui=5.0, est=4.200624906047532, details={'was_impossible': False}),
#  Prediction(uid='Wendi', iid=151045, r_ui=2.0, est=4.175539920965752, details={'was_impossible': False}),
#  Prediction(uid='lea.chadwell', iid=165525, r_ui=5.0, est=3.4733383351984575, details={'was_impossible': False}),
#  Prediction(uid='Rebecca', iid=427567, r_ui=4.0, est=4.18326685093607, details={'was_impossible': False}),
#  Prediction(uid='erin', iid=136482, r_ui=3.0, est=3.7487943780425255, details={'was_impossible': False}),
#  Prediction(uid='Meags', iid=407044, r_ui=3.0, est=3.6292961572816216, details={'was_impossible': False}),
#  Prediction(uid='leiafeliz22', iid=657242, r_ui=3.0, est=3.6112742956289594, details={'was_impossible': False}),
#  Prediction(uid='jlzickefoose52', iid=647235, r_ui=4.0, est=4.072422137227379, details={'was_impossible': False}),
#  Prediction(uid='Dana', iid=752094, r_ui=3.0, est=3.898036213081732, details={'was_impossible': False}),
#  Prediction(uid='Melanie', iid=581432, r_ui=4.0, est=3.6111850830601733, details={'was_impossible': False}),
#  Prediction(uid='phams', iid=478481, r_ui=3.0, est=4.0217366846838996, details={'was_impossible': False}),
#  Prediction(uid='Gracie', iid=200824, r_ui=3.0, est=4.077826304920968, details={'was_impossible': False}),
#  Prediction(uid='riskandreason', iid=696347, r_ui=2.0, est=4.020195465147212, details={'was_impossible': False}),
#  Prediction(uid='Sonja', iid=152702, r_ui=4.0, est=3.900537864810419, details={'was_impossible': False}),
#  Prediction(uid='curiouslybrighteyed', iid=427999, r_ui=5.0, est=4.127024821730655, details={'was_impossible': False}),
#  Prediction(uid='Andrea', iid=647235, r_ui=4.0, est=4.11988463811955, details={'was_impossible': False}),
#  Prediction(uid='Brittany', iid=397005, r_ui=5.0, est=4.139611722262222, details={'was_impossible': False}),
#  Prediction(uid='snufflufagus', iid=423572, r_ui=3.0, est=3.977000089833266, details={'was_impossible': False}),
#  Prediction(uid='ebeth9161971', iid=314980, r_ui=5.0, est=3.94784260007707, details={'was_impossible': False}),
#  Prediction(uid='Ana', iid=169727, r_ui=4.0, est=3.5834577070563327, details={'was_impossible': False}),
#  Prediction(uid='Faith', iid=682698, r_ui=5.0, est=4.196482707941117, details={'was_impossible': False}),
#  Prediction(uid='Classical Trendsetter', iid=630114, r_ui=5.0, est=4.028255165184491, details={'was_impossible': False}),
#  Prediction(uid='jking.style', iid=659701, r_ui=4.0, est=4.287015503587077, details={'was_impossible': False}),
#  Prediction(uid='Amanda', iid=161514, r_ui=3.0, est=4.014484767170146, details={'was_impossible': False}),
#  Prediction(uid='Lori', iid=143287, r_ui=5.0, est=4.235676868805965, details={'was_impossible': False}),
#  Prediction(uid='Maria', iid=650890, r_ui=4.0, est=4.181281060637415, details={'was_impossible': False}),
#  Prediction(uid='kaleidolace', iid=397005, r_ui=4.0, est=4.023432592418622, details={'was_impossible': False}),
#  Prediction(uid='Olivia', iid=661169, r_ui=5.0, est=3.6114926763031927, details={'was_impossible': False}),
#  Prediction(uid='Nicki', iid=697835, r_ui=3.0, est=3.959782054689594, details={'was_impossible': False}),
#  Prediction(uid='Samantha', iid=502359, r_ui=5.0, est=3.961122116119279, details={'was_impossible': False}),
#  Prediction(uid='erciliamedeiros', iid=404229, r_ui=4.0, est=3.9813993131497027, details={'was_impossible': False}),
#  Prediction(uid='Kimberly', iid=168387, r_ui=5.0, est=3.875777452237299, details={'was_impossible': False}),
#  Prediction(uid='92dresstoimpress', iid=402677, r_ui=2.0, est=3.939214492623006, details={'was_impossible': False}),
#  Prediction(uid='alysiadsmith', iid=314980, r_ui=4.0, est=4.109620362832725, details={'was_impossible': False}),
#  Prediction(uid='daspang', iid=520945, r_ui=5.0, est=3.706800253620124, details={'was_impossible': False}),
#  Prediction(uid='Norma', iid=752094, r_ui=4.0, est=3.7480559599544767, details={'was_impossible': False}),
#  Prediction(uid='mary', iid=404557, r_ui=3.0, est=3.6313144631071674, details={'was_impossible': False}),
#  Prediction(uid='sitinuraisah', iid=170806, r_ui=4.0, est=4.061435143404398, details={'was_impossible': False}),
#  Prediction(uid='Leiney', iid=757242, r_ui=4.0, est=3.841740944726862, details={'was_impossible': False}),
#  Prediction(uid='Courtney', iid=416942, r_ui=5.0, est=4.047633734501506, details={'was_impossible': False}),
#  Prediction(uid='mary.jozefiak', iid=298256, r_ui=5.0, est=3.9037997349687004, details={'was_impossible': False}),
#  Prediction(uid='Shannon', iid=407134, r_ui=3.0, est=3.483069136889058, details={'was_impossible': False}),
#  Prediction(uid='Sky', iid=391519, r_ui=4.0, est=4.037822071661664, details={'was_impossible': False}),
#  Prediction(uid='Jen', iid=175771, r_ui=4.0, est=4.01777336524447, details={'was_impossible': False}),
#  Prediction(uid='Abby0073', iid=573631, r_ui=1.0, est=4.0036502557920794, details={'was_impossible': False}),
#  Prediction(uid='Alexis', iid=454764, r_ui=5.0, est=4.228322670530419, details={'was_impossible': False}),
#  Prediction(uid='Christina', iid=397005, r_ui=4.0, est=4.168588744255313, details={'was_impossible': False}),
#  Prediction(uid='jenscrivener', iid=427041, r_ui=5.0, est=4.285991277237182, details={'was_impossible': False}),
#  Prediction(uid='Christine', iid=165525, r_ui=4.0, est=3.5121119105564187, details={'was_impossible': False}),
#  Prediction(uid='lcbonlineshopping', iid=539980, r_ui=5.0, est=4.00167636095441, details={'was_impossible': False}),
#  Prediction(uid='kiddycaz', iid=380801, r_ui=3.0, est=4.33261576648374, details={'was_impossible': False}),
#  Prediction(uid='leslie', iid=484879, r_ui=5.0, est=3.6193159740477334, details={'was_impossible': False}),
#  Prediction(uid='Emma', iid=152702, r_ui=5.0, est=3.986555926494837, details={'was_impossible': False}),
#  Prediction(uid='denisemcpage', iid=298256, r_ui=4.0, est=3.9037997349687004, details={'was_impossible': False}),
#  Prediction(uid='Erica', iid=668696, r_ui=3.0, est=4.164344721868584, details={'was_impossible': False}),
#  Prediction(uid='Hannah', iid=338596, r_ui=5.0, est=4.205565236869648, details={'was_impossible': False}),
#  Prediction(uid='Rani', iid=175771, r_ui=2.0, est=3.9986113524869005, details={'was_impossible': False}),
#  Prediction(uid='Shannonigans', iid=684079, r_ui=3.0, est=3.9954528168072305, details={'was_impossible': False}),
#  Prediction(uid='Meghan', iid=394692, r_ui=4.0, est=4.120283307491153, details={'was_impossible': False}),
#  Prediction(uid='Kerry', iid=604607, r_ui=4.0, est=4.276531681103871, details={'was_impossible': False}),
#  Prediction(uid='friendship_emma', iid=407134, r_ui=3.0, est=3.6666484195543663, details={'was_impossible': False}),
#  Prediction(uid='Brandi', iid=338596, r_ui=5.0, est=3.9623643066269976, details={'was_impossible': False}),
#  Prediction(uid='Candice', iid=314980, r_ui=5.0, est=4.041536397493729, details={'was_impossible': False}),
#  Prediction(uid='bernarbl', iid=668696, r_ui=5.0, est=4.145036055124333, details={'was_impossible': False}),
#  Prediction(uid='Holly', iid=693560, r_ui=4.0, est=3.4134012848116924, details={'was_impossible': False}),
#  Prediction(uid='d_magabilin', iid=657081, r_ui=3.0, est=3.6386614380678113, details={'was_impossible': False}),
#  Prediction(uid='Piper', iid=146231, r_ui=5.0, est=3.478512337050486, details={'was_impossible': False}),
#  Prediction(uid='Dominique', iid=656645, r_ui=3.0, est=3.7033570900225747, details={'was_impossible': False}),
#  Prediction(uid='emilie.patton', iid=755526, r_ui=2.0, est=3.736513423211126, details={'was_impossible': False}),
#  Prediction(uid='v_amanda_lee', iid=298256, r_ui=4.0, est=3.9037997349687004, details={'was_impossible': False}),
#  Prediction(uid='shadowdancer917', iid=397005, r_ui=5.0, est=4.023432592418622, details={'was_impossible': False}),
#  Prediction(uid='Claire', iid=478481, r_ui=5.0, est=4.100426807755183, details={'was_impossible': False}),
#  Prediction(uid='robinsonka25', iid=142651, r_ui=3.0, est=3.7764376183178188, details={'was_impossible': False}),
#  Prediction(uid='Caryn', iid=397005, r_ui=5.0, est=4.094216845636637, details={'was_impossible': False}),
#  Prediction(uid='marialuciacorrea', iid=654585, r_ui=3.0, est=3.65814900214226, details={'was_impossible': False}),
#  Prediction(uid='Carly', iid=167315, r_ui=3.0, est=3.6277655119819183, details={'was_impossible': False}),
#  Prediction(uid='theresa.carpine', iid=397005, r_ui=4.0, est=4.023432592418622, details={'was_impossible': False}),
#  Prediction(uid='Kelli', iid=539980, r_ui=5.0, est=4.167022432012217, details={'was_impossible': False}),
#  Prediction(uid='eriddle3', iid=659083, r_ui=3.0, est=4.3142966260551345, details={'was_impossible': False}),
#  Prediction(uid='Robin', iid=477210, r_ui=3.0, est=3.5333787239899923, details={'was_impossible': False}),
#  Prediction(uid='shecht313', iid=655211, r_ui=4.0, est=3.857087279999764, details={'was_impossible': False}),
#  Prediction(uid='carrievorpahl', iid=397005, r_ui=4.0, est=4.023432592418622, details={'was_impossible': False}),
#  Prediction(uid='Shaun', iid=146231, r_ui=4.0, est=3.595399525863095, details={'was_impossible': False}),
#  Prediction(uid='Taylor', iid=697835, r_ui=3.0, est=4.1087716415434965, details={'was_impossible': False}),
#  Prediction(uid='makenab', iid=404229, r_ui=5.0, est=3.9332779160405216, details={'was_impossible': False}),
#  Prediction(uid='tkingjw', iid=169727, r_ui=2.0, est=3.640524735375735, details={'was_impossible': False}),
#  Prediction(uid='ilea214', iid=391519, r_ui=3.0, est=4.034172310118744, details={'was_impossible': False}),
#  Prediction(uid='missmaddimaddi', iid=125442, r_ui=4.0, est=4.191908680175277, details={'was_impossible': False}),
#  Prediction(uid='Nicole', iid=175771, r_ui=4.0, est=4.001007379967175, details={'was_impossible': False}),
#  Prediction(uid='meggie.willner', iid=416942, r_ui=5.0, est=4.086299107609566, details={'was_impossible': False}),
#  Prediction(uid='janayafe', iid=427999, r_ui=3.0, est=4.096884529262327, details={'was_impossible': False}),
#  Prediction(uid='tiffany.h.hui', iid=781127, r_ui=5.0, est=4.132627086593505, details={'was_impossible': False}),
#  Prediction(uid='izzy.erskine', iid=538258, r_ui=3.0, est=3.8611200567042716, details={'was_impossible': False}),
# ...
#  Prediction(uid='kendyl.work824', iid=170806, r_ui=4.0, est=4.017173120712967, details={'was_impossible': False}),
#  Prediction(uid='kate.franco', iid=520945, r_ui=3.0, est=3.6038480888815343, details={'was_impossible': False}),
#  Prediction(uid='katyaleigh', iid=412737, r_ui=2.0, est=3.6130366380218577, details={'was_impossible': False}),
#  Prediction(uid='hr.wallflower', iid=392144, r_ui=5.0, est=4.16316305930402, details={'was_impossible': False}),
#  Prediction(uid='t_nolan369', iid=520958, r_ui=5.0, est=3.7751817635286153, details={'was_impossible': False}),
#  Prediction(uid='ktheg11', iid=668696, r_ui=4.0, est=4.145036055124333, details={'was_impossible': False}),
#  Prediction(uid='Kathryn', iid=146231, r_ui=4.0, est=3.404593273088832, details={'was_impossible': False}),
#  Prediction(uid='alanna_neff', iid=507565, r_ui=4.0, est=4.015818902326562, details={'was_impossible': False}),
#  Prediction(uid='shan.marie.cook', iid=152702, r_ui=4.0, est=3.8914841454859035, details={'was_impossible': False}),
#  Prediction(uid='Chasie', iid=454030, r_ui=4.0, est=4.116906351164022, details={'was_impossible': False}),
#  Prediction(uid='shykiki4466', iid=697835, r_ui=5.0, est=4.127749161295464, details={'was_impossible': False}),
#  Prediction(uid='Jhonda', iid=175771, r_ui=5.0, est=3.9986113524869005, details={'was_impossible': False}),
#  Prediction(uid='msbook_girl', iid=380801, r_ui=4.0, est=3.9087306242762345, details={'was_impossible': False}),
#  Prediction(uid='melodyrocks', iid=152513, r_ui=3.0, est=3.970577700065132, details={'was_impossible': False}),
#  Prediction(uid='myacupcake', iid=404229, r_ui=3.0, est=3.9555569783628792, details={'was_impossible': False}),
#  Prediction(uid='Miranda', iid=429442, r_ui=4.0, est=4.49206687949811, details={'was_impossible': False}),
#  Prediction(uid='holly.decaigny', iid=416738, r_ui=4.0, est=4.0065017586254, details={'was_impossible': False}),
#  Prediction(uid='iloveyougermany', iid=314980, r_ui=3.0, est=3.8645932518101125, details={'was_impossible': False}),
#  Prediction(uid='Sabrina', iid=778295, r_ui=3.0, est=3.738479897745298, details={'was_impossible': False}),
#  Prediction(uid='sweetheartjess', iid=417902, r_ui=3.0, est=3.556977595272777, details={'was_impossible': False}),
#  Prediction(uid='acmekat', iid=539980, r_ui=4.0, est=4.00167636095441, details={'was_impossible': False}),
#  Prediction(uid='leitingerej', iid=539980, r_ui=4.0, est=3.8593365758200235, details={'was_impossible': False}),
#  Prediction(uid='Amanda', iid=410934, r_ui=4.0, est=4.017692759648658, details={'was_impossible': False}),
#  Prediction(uid='andreamustain', iid=645822, r_ui=4.0, est=3.977789590228332, details={'was_impossible': False}),
#  Prediction(uid='Paige', iid=774932, r_ui=4.0, est=4.175284736812084, details={'was_impossible': False}),
#  Prediction(uid='Lynda', iid=246671, r_ui=2.0, est=4.171311582342717, details={'was_impossible': False}),
#  Prediction(uid='darrahj82', iid=154411, r_ui=3.0, est=3.8869165368174836, details={'was_impossible': False}),
#  Prediction(uid='Angelica', iid=397005, r_ui=5.0, est=3.9487484073018204, details={'was_impossible': False}),
#  Prediction(uid='Sarah', iid=445254, r_ui=5.0, est=4.340238565252068, details={'was_impossible': False}),
#  Prediction(uid='ljhobbis', iid=723208, r_ui=4.0, est=3.970803199463057, details={'was_impossible': False}),
#  Prediction(uid='lisa.yim', iid=539980, r_ui=4.0, est=3.763122040712867, details={'was_impossible': False}),
#  Prediction(uid='Erin', iid=530472, r_ui=3.0, est=3.7869747868599455, details={'was_impossible': False}),
#  Prediction(uid='Deneen', iid=445254, r_ui=4.0, est=4.338544203930147, details={'was_impossible': False}),
#  Prediction(uid='smileitsnaomi', iid=723977, r_ui=4.0, est=4.191390205772485, details={'was_impossible': False}),
#  Prediction(uid='Sarah', iid=402677, r_ui=3.0, est=3.8296339971158195, details={'was_impossible': False}),
#  Prediction(uid='aliannie2000', iid=775870, r_ui=4.0, est=3.869820001179546, details={'was_impossible': False}),
#  Prediction(uid='Yota', iid=200824, r_ui=4.0, est=3.8822064496043067, details={'was_impossible': False}),
#  Prediction(uid='Kat', iid=406357, r_ui=4.0, est=4.070509989027841, details={'was_impossible': False}),
#  Prediction(uid='feesome', iid=124124, r_ui=3.0, est=3.626755788185275, details={'was_impossible': False}),
#  Prediction(uid='Jennifer', iid=125442, r_ui=4.0, est=4.27117810420236, details={'was_impossible': False}),
#  Prediction(uid='Jennifer', iid=427567, r_ui=4.0, est=4.044262839644634, details={'was_impossible': False}),
#  Prediction(uid='Georgette', iid=371983, r_ui=4.0, est=4.0872569223502335, details={'was_impossible': False}),
#  Prediction(uid='candyce.muns', iid=752094, r_ui=3.0, est=3.783490231296381, details={'was_impossible': False}),
#  Prediction(uid='Kate', iid=545232, r_ui=4.0, est=3.687697923106771, details={'was_impossible': False}),
#  Prediction(uid='Katie', iid=412737, r_ui=3.0, est=3.5889463983106933, details={'was_impossible': False}),
#  Prediction(uid='rebohman', iid=380801, r_ui=4.0, est=4.033371396385716, details={'was_impossible': False}),
#  Prediction(uid='akmeander', iid=538258, r_ui=5.0, est=3.841662226609331, details={'was_impossible': False}),
#  Prediction(uid='ModCloth', iid=757508, r_ui=4.0, est=4.271657000008813, details={'was_impossible': False}),
#  Prediction(uid='Sapphire', iid=155572, r_ui=5.0, est=4.198508106432786, details={'was_impossible': False}),
#  Prediction(uid='Alexandra', iid=162470, r_ui=4.0, est=4.063551586609331, details={'was_impossible': False}),
#  Prediction(uid='nettynoo', iid=539980, r_ui=2.0, est=4.072590885105336, details={'was_impossible': False}),
#  Prediction(uid='dmcoraldatabase', iid=407574, r_ui=2.0, est=3.5609607764290536, details={'was_impossible': False}),
#  Prediction(uid='banning_sarah', iid=796383, r_ui=4.0, est=3.8086193045314496, details={'was_impossible': False}),
#  Prediction(uid='megankms', iid=520945, r_ui=4.0, est=3.6038480888815343, details={'was_impossible': False}),
#  Prediction(uid='ambertherussell', iid=806856, r_ui=4.0, est=4.340118434130667, details={'was_impossible': False}),
#  Prediction(uid='allisonlovell', iid=152513, r_ui=5.0, est=4.009188833779365, details={'was_impossible': False}),
#  Prediction(uid='esteticaessenze', iid=659701, r_ui=5.0, est=4.361489207477224, details={'was_impossible': False}),
#  Prediction(uid='Gracie', iid=146231, r_ui=2.0, est=3.6162856573630036, details={'was_impossible': False}),
#  Prediction(uid='Catherine', iid=502359, r_ui=5.0, est=3.8596092203429695, details={'was_impossible': False}),
#  Prediction(uid='adapsauski', iid=650890, r_ui=5.0, est=4.243264007730928, details={'was_impossible': False}),
#  Prediction(uid='marissa', iid=645822, r_ui=3.0, est=3.9159304358603952, details={'was_impossible': False}),
#  Prediction(uid='upixie', iid=163558, r_ui=5.0, est=4.097302740132874, details={'was_impossible': False}),
#  Prediction(uid='Merissa', iid=338596, r_ui=4.0, est=4.101535008722422, details={'was_impossible': False}),
#  Prediction(uid='rsmorin', iid=154411, r_ui=3.0, est=3.789708399547389, details={'was_impossible': False}),
#  Prediction(uid='Lisa', iid=380801, r_ui=4.0, est=4.027950941831067, details={'was_impossible': False}),
#  Prediction(uid='ringerem', iid=401773, r_ui=3.0, est=4.060172026888877, details={'was_impossible': False}),
#  Prediction(uid='shaadys', iid=796383, r_ui=3.0, est=3.7588000368739105, details={'was_impossible': False}),
#  Prediction(uid='Amy Joy', iid=126885, r_ui=5.0, est=3.841032066393261, details={'was_impossible': False}),
#  Prediction(uid='Yota', iid=400541, r_ui=5.0, est=4.247965928177743, details={'was_impossible': False}),
#  Prediction(uid='Sara', iid=661775, r_ui=5.0, est=3.690686736076279, details={'was_impossible': False}),
#  Prediction(uid='mollyrskiles', iid=668696, r_ui=5.0, est=4.137842756120262, details={'was_impossible': False}),
#  Prediction(uid='Jennifer', iid=780724, r_ui=5.0, est=3.7804215487812565, details={'was_impossible': False}),
#  Prediction(uid='Misty', iid=412003, r_ui=3.0, est=3.7374282551919222, details={'was_impossible': False}),
#  Prediction(uid='Holly', iid=429442, r_ui=2.0, est=3.7819688192128678, details={'was_impossible': False}),
#  Prediction(uid='kathrynkolonic', iid=539980, r_ui=5.0, est=4.1580588101830145, details={'was_impossible': False}),
#  Prediction(uid='ammorrison', iid=715501, r_ui=5.0, est=3.501623601346125, details={'was_impossible': False}),
#  Prediction(uid='hpkrijnen', iid=800643, r_ui=3.0, est=3.766028544076392, details={'was_impossible': False}),
#  Prediction(uid='Sarah', iid=454030, r_ui=3.0, est=4.115042226237166, details={'was_impossible': False}),
#  Prediction(uid='dnovelli', iid=175771, r_ui=4.0, est=3.9986113524869005, details={'was_impossible': False}),
#  Prediction(uid='loooning', iid=756722, r_ui=3.0, est=3.557537364864205, details={'was_impossible': False}),
#  Prediction(uid='Heather K', iid=263611, r_ui=3.0, est=4.017091372933461, details={'was_impossible': False}),
#  Prediction(uid='nmacmillan', iid=169727, r_ui=1.0, est=3.498704252905174, details={'was_impossible': False}),
#  Prediction(uid='tonnalay', iid=173879, r_ui=4.0, est=3.946205924247049, details={'was_impossible': False}),
#  Prediction(uid='Vanessa', iid=401773, r_ui=4.0, est=4.051752929095296, details={'was_impossible': False}),
#  Prediction(uid='Claire', iid=654585, r_ui=4.0, est=3.861032055518946, details={'was_impossible': False}),
#  Prediction(uid='WannabeSurfer', iid=571113, r_ui=3.0, est=4.042314389158184, details={'was_impossible': False}),
#  Prediction(uid='Nathalie', iid=806856, r_ui=5.0, est=4.4537056941623465, details={'was_impossible': False}),
#  Prediction(uid='Marissa', iid=714723, r_ui=5.0, est=4.312606303664316, details={'was_impossible': False}),
#  Prediction(uid='aloehr00', iid=661775, r_ui=2.0, est=3.7333548316506295, details={'was_impossible': False}),
#  Prediction(uid='kellyd419', iid=151045, r_ui=5.0, est=4.070211294529476, details={'was_impossible': False}),
#  Prediction(uid='jessteve412', iid=538258, r_ui=3.0, est=3.933304197041009, details={'was_impossible': False}),
#  Prediction(uid='Lula', iid=474002, r_ui=3.0, est=3.6324804848981995, details={'was_impossible': False}),
#  Prediction(uid='rebgro', iid=477210, r_ui=4.0, est=3.6442314433793124, details={'was_impossible': False}),
#  Prediction(uid='Amanda', iid=163185, r_ui=3.0, est=4.001517048212346, details={'was_impossible': False}),
#  Prediction(uid='courtneyfreng', iid=412737, r_ui=2.0, est=3.656873650670193, details={'was_impossible': False}),
#  Prediction(uid='nfwardle', iid=401651, r_ui=4.0, est=4.071499027474611, details={'was_impossible': False}),
#  Prediction(uid='Rainingstairs', iid=165525, r_ui=3.0, est=3.507470515422066, details={'was_impossible': False}),
#  Prediction(uid='lauramariewarfield', iid=693560, r_ui=5.0, est=3.6720961695224537, details={'was_impossible': False}),
#  Prediction(uid='postla01', iid=353933, r_ui=4.0, est=4.066046557479886, details={'was_impossible': False}),
#  Prediction(uid='neigeux628', iid=175771, r_ui=4.0, est=3.9986113524869005, details={'was_impossible': False}),
#  Prediction(uid='katethebug', iid=655211, r_ui=5.0, est=3.857087279999764, details={'was_impossible': False}),
#  Prediction(uid='raybgirl16', iid=445254, r_ui=3.0, est=4.338544203930147, details={'was_impossible': False}),
#  Prediction(uid='purpleheather84', iid=781127, r_ui=3.0, est=4.132627086593505, details={'was_impossible': False}),
#  Prediction(uid='bwisekal', iid=645822, r_ui=5.0, est=3.921698501424481, details={'was_impossible': False}),
#  Prediction(uid='koko6711', iid=376359, r_ui=4.0, est=3.9193877436844433, details={'was_impossible': False}),
#  Prediction(uid='ajreyes138', iid=210299, r_ui=5.0, est=3.7323601045548473, details={'was_impossible': False}),
#  Prediction(uid='sarahestubbs', iid=429442, r_ui=5.0, est=3.961726961374071, details={'was_impossible': False}),
#  Prediction(uid='bumblebeester', iid=750256, r_ui=4.0, est=3.8194458519872025, details={'was_impossible': False}),
#  Prediction(uid='feedtheworld3', iid=171125, r_ui=4.0, est=3.804906248958087, details={'was_impossible': False}),
#  Prediction(uid='Kate', iid=338596, r_ui=4.0, est=4.076665201904454, details={'was_impossible': False}),
#  Prediction(uid='Palma', iid=787518, r_ui=4.0, est=4.128234340342304, details={'was_impossible': False}),
#  Prediction(uid='MountainMerlin', iid=298818, r_ui=5.0, est=4.000289274807007, details={'was_impossible': False}),
#  Prediction(uid='rettingsb', iid=697835, r_ui=5.0, est=4.014867316600546, details={'was_impossible': False}),
#  Prediction(uid='Madre', iid=391519, r_ui=4.0, est=4.083317981903166, details={'was_impossible': False}),
#  Prediction(uid='Emma', iid=639328, r_ui=4.0, est=4.060723947310622, details={'was_impossible': False}),
#  Prediction(uid='rettler828', iid=792842, r_ui=3.0, est=3.7834071575304584, details={'was_impossible': False}),
#  Prediction(uid='Michele', iid=657081, r_ui=3.0, est=3.9232973139454095, details={'was_impossible': False}),
#  Prediction(uid='Sarah', iid=429442, r_ui=5.0, est=4.0302942053534725, details={'was_impossible': False}),
#  Prediction(uid='denisebelmonte', iid=630114, r_ui=5.0, est=4.093494723920241, details={'was_impossible': False}),
#  Prediction(uid='rmkearney1421', iid=656645, r_ui=5.0, est=3.550478434900391, details={'was_impossible': False}),
#  Prediction(uid='Lauren', iid=404229, r_ui=4.0, est=4.042993231069572, details={'was_impossible': False}),
#  Prediction(uid='Debbie', iid=210299, r_ui=4.0, est=3.4309367229038426, details={'was_impossible': False}),
#  Prediction(uid='m.sutt4', iid=723977, r_ui=5.0, est=4.2443501279541636, details={'was_impossible': False}),
#  Prediction(uid='karkashnyc', iid=340237, r_ui=5.0, est=4.292198869267383, details={'was_impossible': False}),
#  Prediction(uid='shera34', iid=668696, r_ui=4.0, est=4.136042803601898, details={'was_impossible': False}),
#  Prediction(uid='devonchaos78', iid=756073, r_ui=5.0, est=4.204104945106857, details={'was_impossible': False}),
#  Prediction(uid='kinkylok', iid=269063, r_ui=4.0, est=4.267741493804239, details={'was_impossible': False}),
#  Prediction(uid='Sara', iid=765620, r_ui=3.0, est=3.6038283357425813, details={'was_impossible': False}),
#  Prediction(uid='Michelle', iid=146231, r_ui=5.0, est=3.5723196569798406, details={'was_impossible': False}),
#  Prediction(uid='Treazure', iid=407134, r_ui=3.0, est=3.6666484195543663, details={'was_impossible': False}),
#  Prediction(uid='kallyspersonal', iid=399074, r_ui=2.0, est=4.014195362796389, details={'was_impossible': False}),
#  Prediction(uid='Susan', iid=697835, r_ui=5.0, est=4.149719758181391, details={'was_impossible': False}),
#  Prediction(uid='hamiethehamster', iid=756073, r_ui=4.0, est=3.99375701986216, details={'was_impossible': False}),
#  Prediction(uid='Paloma', iid=401773, r_ui=3.0, est=3.8891018182078527, details={'was_impossible': False}),
#  Prediction(uid='devyn', iid=162470, r_ui=4.0, est=4.071323369515652, details={'was_impossible': False}),
#  Prediction(uid='Rachel', iid=445254, r_ui=5.0, est=4.375456364581549, details={'was_impossible': False}),
#  Prediction(uid='Gail', iid=407044, r_ui=3.0, est=3.4550029379367544, details={'was_impossible': False}),
#  Prediction(uid='Amanda', iid=391519, r_ui=4.0, est=4.082820430367249, details={'was_impossible': False}),
#  Prediction(uid='taylorall', iid=414857, r_ui=5.0, est=4.082992371034622, details={'was_impossible': False}),
#  Prediction(uid='shazia.hassam', iid=129268, r_ui=4.0, est=3.8774482574554963, details={'was_impossible': False}),
#  Prediction(uid='Katherine', iid=806856, r_ui=5.0, est=4.162218809825423, details={'was_impossible': False}),
#  Prediction(uid='Jane', iid=659701, r_ui=5.0, est=4.403896504986849, details={'was_impossible': False}),
#  Prediction(uid='Christy', iid=147714, r_ui=5.0, est=4.332137092801503, details={'was_impossible': False}),
#  Prediction(uid='itymgurl', iid=481011, r_ui=4.0, est=3.509248771528896, details={'was_impossible': False}),
#  Prediction(uid='linzeyb08', iid=146231, r_ui=3.0, est=3.5295651201296843, details={'was_impossible': False}),
#  ...]

# %%
user_34_prediction = svd.predict('ana',715501)
user_34_prediction
#Checking out a random prediction for 'ana'
# Out:
# Prediction(uid='ana', iid=715501, r_ui=None, est=3.6655835543720725, details={'was_impossible': False})

# %%
user_70_prediction = svd.predict('ana',374614)
user_70_prediction
#Seems 'ana' may prefer item 374614 slightly more than item 715501
# Out:
# Prediction(uid='ana', iid=374614, r_ui=None, est=4.086141677702061, details={'was_impossible': False})
